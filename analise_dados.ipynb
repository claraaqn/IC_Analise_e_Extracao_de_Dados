# %%
import pandas as pd

# %% [markdown]
# #### 2004

# %%
ca_2004_01 = pd.read_csv("rsc/ca-2004-01.csv", sep=';')

# %%
ca_2004_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP   SOROCABA
# 4             SE             SP   SOROCABA
#
#                                              Revenda      CNPJ da Revenda  \
# 0                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 4  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
#
#                 Nome da Rua Numero Rua          Complemento          Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# ...

# %%
ca_2004_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281531 entries, 0 to 281530
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     281531 non-null  object
#  1   Estado - Sigla     281531 non-null  object
#  2   Municipio          281531 non-null  object
#  3   Revenda            281531 non-null  object
#  4   CNPJ da Revenda    281531 non-null  object
#  5   Nome da Rua        281531 non-null  object
#  6   Numero Rua         281358 non-null  object
#  7   Complemento        92233 non-null   object
#  8   Bairro             280713 non-null  object
#  9   Cep                281531 non-null  object
#  10  Produto            281531 non-null  object
#  11  Data da Coleta     281531 non-null  object
#  12  Valor de Venda     281531 non-null  object
#  13  Valor de Compra    195235 non-null  object
#  14  Unidade de Medida  281531 non-null  object
# ...

# %%
ca_2004_01['Valor de Venda'].unique()
# Out:
# array(['1,967', '0,899', '1,299', ..., '1,413', '2,092', '1,914'],
#       dtype=object)

# %%
ca_2004_01['Valor de Venda'] = ca_2004_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2004_01['Valor de Compra'] = ca_2004_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2004_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281531 entries, 0 to 281530
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     281531 non-null  object
#  1   Estado - Sigla     281531 non-null  object
#  2   Municipio          281531 non-null  object
#  3   Revenda            281531 non-null  object
#  4   CNPJ da Revenda    281531 non-null  object
#  5   Nome da Rua        281531 non-null  object
#  6   Numero Rua         281358 non-null  object
#  7   Complemento        92233 non-null   object
#  8   Bairro             280713 non-null  object
#  9   Cep                281531 non-null  object
#  10  Produto            281531 non-null  object
#  11  Data da Coleta     281531 non-null  object
#  12  Valor de Venda     281531 non-null  float64
#  13  Valor de Compra    195235 non-null  float64
#  14  Unidade de Medida  281531 non-null  object
# ...

# %%
ca_2004_02 = pd.read_csv("rsc/ca-2004-02.csv", sep=';')

# %%
ca_2004_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla      Municipio  \
# 0             CO             MS   CAMPO GRANDE
# 1             CO             MS   CAMPO GRANDE
# 2             CO             MS   CAMPO GRANDE
# 3             CO             MT  ALTA FLORESTA
# 4             CO             MT  ALTA FLORESTA
#
#                               Revenda      CNPJ da Revenda  \
# 0  AUTO POSTO APARECIDA DO NORTE LTDA   86.807.609/0001-92
# 1  AUTO POSTO APARECIDA DO NORTE LTDA   86.807.609/0001-92
# 2  AUTO POSTO APARECIDA DO NORTE LTDA   86.807.609/0001-92
# 3              AUTO POSTO BURIOL LTDA   04.481.758/0001-40
# 4              AUTO POSTO BURIOL LTDA   04.481.758/0001-40
#
#                Nome da Rua Numero Rua   Complemento             Bairro  \
# 0            RUA BRILHANTE      2,787           NaN  VILA BANDEIRANTES
# 1            RUA BRILHANTE      2,787           NaN  VILA BANDEIRANTES
# 2            RUA BRILHANTE      2,787           NaN  VILA BANDEIRANTES
# ...

# %%
ca_2004_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915317 entries, 0 to 915316
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     915317 non-null  object
#  1   Estado - Sigla     915317 non-null  object
#  2   Municipio          915317 non-null  object
#  3   Revenda            915317 non-null  object
#  4   CNPJ da Revenda    915317 non-null  object
#  5   Nome da Rua        915317 non-null  object
#  6   Numero Rua         914840 non-null  object
#  7   Complemento        299051 non-null  object
#  8   Bairro             912676 non-null  object
#  9   Cep                915317 non-null  object
#  10  Produto            915317 non-null  object
#  11  Data da Coleta     915317 non-null  object
#  12  Valor de Venda     915317 non-null  object
#  13  Valor de Compra    626609 non-null  object
#  14  Unidade de Medida  915317 non-null  object
# ...

# %%
ca_2004_02['Valor de Venda'] = ca_2004_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2004_02['Valor de Compra'] = ca_2004_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2004_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915317 entries, 0 to 915316
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     915317 non-null  object
#  1   Estado - Sigla     915317 non-null  object
#  2   Municipio          915317 non-null  object
#  3   Revenda            915317 non-null  object
#  4   CNPJ da Revenda    915317 non-null  object
#  5   Nome da Rua        915317 non-null  object
#  6   Numero Rua         914840 non-null  object
#  7   Complemento        299051 non-null  object
#  8   Bairro             912676 non-null  object
#  9   Cep                915317 non-null  object
#  10  Produto            915317 non-null  object
#  11  Data da Coleta     915317 non-null  object
#  12  Valor de Venda     915317 non-null  float64
#  13  Valor de Compra    626609 non-null  float64
#  14  Unidade de Medida  915317 non-null  object
# ...

# %% [markdown]
# #### 2005

# %%
ca_2005_01 = pd.read_csv("rsc/ca-2005-01.csv", sep=';')

# %%
ca_2005_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP   SOROCABA
# 4             SE             SP   SOROCABA
#
#                                              Revenda      CNPJ da Revenda  \
# 0                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 4  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
#
#                 Nome da Rua Numero Rua          Complemento          Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# ...

# %%
ca_2005_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912729 entries, 0 to 912728
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     912729 non-null  object
#  1   Estado - Sigla     912729 non-null  object
#  2   Municipio          912729 non-null  object
#  3   Revenda            912729 non-null  object
#  4   CNPJ da Revenda    912729 non-null  object
#  5   Nome da Rua        912729 non-null  object
#  6   Numero Rua         912225 non-null  object
#  7   Complemento        297241 non-null  object
#  8   Bairro             910112 non-null  object
#  9   Cep                912729 non-null  object
#  10  Produto            912729 non-null  object
#  11  Data da Coleta     912729 non-null  object
#  12  Valor de Venda     912729 non-null  object
#  13  Valor de Compra    612689 non-null  object
#  14  Unidade de Medida  912729 non-null  object
# ...

# %%
ca_2005_01['Valor de Venda'] = ca_2005_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2005_01['Valor de Compra'] = ca_2005_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2005_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912729 entries, 0 to 912728
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     912729 non-null  object
#  1   Estado - Sigla     912729 non-null  object
#  2   Municipio          912729 non-null  object
#  3   Revenda            912729 non-null  object
#  4   CNPJ da Revenda    912729 non-null  object
#  5   Nome da Rua        912729 non-null  object
#  6   Numero Rua         912225 non-null  object
#  7   Complemento        297241 non-null  object
#  8   Bairro             910112 non-null  object
#  9   Cep                912729 non-null  object
#  10  Produto            912729 non-null  object
#  11  Data da Coleta     912729 non-null  object
#  12  Valor de Venda     912729 non-null  float64
#  13  Valor de Compra    612689 non-null  float64
#  14  Unidade de Medida  912729 non-null  object
# ...

# %%
ca_2005_02 = pd.read_csv("rsc/ca-2005-02.csv", sep=';')

# %%
ca_2005_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP   SOROCABA
# 4             SE             SP   SOROCABA
#
#                                              Revenda      CNPJ da Revenda  \
# 0                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 4  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
#
#                 Nome da Rua Numero Rua          Complemento          Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# ...

# %%
ca_2005_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741813 entries, 0 to 741812
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     741813 non-null  object
#  1   Estado - Sigla     741813 non-null  object
#  2   Municipio          741813 non-null  object
#  3   Revenda            741813 non-null  object
#  4   CNPJ da Revenda    741813 non-null  object
#  5   Nome da Rua        741813 non-null  object
#  6   Numero Rua         741421 non-null  object
#  7   Complemento        228784 non-null  object
#  8   Bairro             739873 non-null  object
#  9   Cep                741813 non-null  object
#  10  Produto            741813 non-null  object
#  11  Data da Coleta     741813 non-null  object
#  12  Valor de Venda     741813 non-null  object
#  13  Valor de Compra    455397 non-null  object
#  14  Unidade de Medida  741813 non-null  object
# ...

# %%
ca_2005_02['Valor de Venda'] = ca_2005_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2005_02['Valor de Compra'] = ca_2005_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2005_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741813 entries, 0 to 741812
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     741813 non-null  object
#  1   Estado - Sigla     741813 non-null  object
#  2   Municipio          741813 non-null  object
#  3   Revenda            741813 non-null  object
#  4   CNPJ da Revenda    741813 non-null  object
#  5   Nome da Rua        741813 non-null  object
#  6   Numero Rua         741421 non-null  object
#  7   Complemento        228784 non-null  object
#  8   Bairro             739873 non-null  object
#  9   Cep                741813 non-null  object
#  10  Produto            741813 non-null  object
#  11  Data da Coleta     741813 non-null  object
#  12  Valor de Venda     741813 non-null  float64
#  13  Valor de Compra    455397 non-null  float64
#  14  Unidade de Medida  741813 non-null  object
# ...

# %% [markdown]
# #### 2006

# %%
ca_2006_01 = pd.read_csv("rsc/ca-2006-01.csv", sep=';')

# %%
ca_2006_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP   SOROCABA
# 4             SE             SP   SOROCABA
#
#                                              Revenda      CNPJ da Revenda  \
# 0                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                           AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 4  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
#
#                 Nome da Rua Numero Rua          Complemento          Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ      BONSUCESSO
# ...

# %%
ca_2006_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868880 entries, 0 to 868879
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     868880 non-null  object
#  1   Estado - Sigla     868880 non-null  object
#  2   Municipio          868880 non-null  object
#  3   Revenda            868880 non-null  object
#  4   CNPJ da Revenda    868880 non-null  object
#  5   Nome da Rua        868880 non-null  object
#  6   Numero Rua         868492 non-null  object
#  7   Complemento        259035 non-null  object
#  8   Bairro             866404 non-null  object
#  9   Cep                868880 non-null  object
#  10  Produto            868880 non-null  object
#  11  Data da Coleta     868880 non-null  object
#  12  Valor de Venda     868880 non-null  object
#  13  Valor de Compra    556915 non-null  object
#  14  Unidade de Medida  868880 non-null  object
# ...

# %%
ca_2006_01['Valor de Venda'] = ca_2006_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2006_01['Valor de Compra'] = ca_2006_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2006_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868880 entries, 0 to 868879
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     868880 non-null  object
#  1   Estado - Sigla     868880 non-null  object
#  2   Municipio          868880 non-null  object
#  3   Revenda            868880 non-null  object
#  4   CNPJ da Revenda    868880 non-null  object
#  5   Nome da Rua        868880 non-null  object
#  6   Numero Rua         868492 non-null  object
#  7   Complemento        259035 non-null  object
#  8   Bairro             866404 non-null  object
#  9   Cep                868880 non-null  object
#  10  Produto            868880 non-null  object
#  11  Data da Coleta     868880 non-null  object
#  12  Valor de Venda     868880 non-null  float64
#  13  Valor de Compra    556915 non-null  float64
#  14  Unidade de Medida  868880 non-null  object
# ...

# %%
ca_2006_02 = pd.read_csv("rsc/ca-2006-02.csv", sep=';')

# %%
ca_2006_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla       Municipio  \
# 0             SE             SP        SOROCABA
# 1             SE             SP        SOROCABA
# 2             SE             SP        SOROCABA
# 3             SE             MG  BELO HORIZONTE
# 4             SE             MG  BELO HORIZONTE
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0057-59
# 4                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0057-59
#
#                          Nome da Rua Numero Rua Complemento          Bairro  \
# 0             RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA
# ...

# %%
ca_2006_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802334 entries, 0 to 802333
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     802334 non-null  object
#  1   Estado - Sigla     802334 non-null  object
#  2   Municipio          802334 non-null  object
#  3   Revenda            802334 non-null  object
#  4   CNPJ da Revenda    802334 non-null  object
#  5   Nome da Rua        802334 non-null  object
#  6   Numero Rua         801983 non-null  object
#  7   Complemento        234348 non-null  object
#  8   Bairro             799888 non-null  object
#  9   Cep                802334 non-null  object
#  10  Produto            802334 non-null  object
#  11  Data da Coleta     802334 non-null  object
#  12  Valor de Venda     802334 non-null  object
#  13  Valor de Compra    533246 non-null  object
#  14  Unidade de Medida  802334 non-null  object
# ...

# %%
ca_2006_02['Valor de Venda'] = ca_2006_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2006_02['Valor de Compra'] = ca_2006_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2006_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802334 entries, 0 to 802333
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     802334 non-null  object
#  1   Estado - Sigla     802334 non-null  object
#  2   Municipio          802334 non-null  object
#  3   Revenda            802334 non-null  object
#  4   CNPJ da Revenda    802334 non-null  object
#  5   Nome da Rua        802334 non-null  object
#  6   Numero Rua         801983 non-null  object
#  7   Complemento        234348 non-null  object
#  8   Bairro             799888 non-null  object
#  9   Cep                802334 non-null  object
#  10  Produto            802334 non-null  object
#  11  Data da Coleta     802334 non-null  object
#  12  Valor de Venda     802334 non-null  float64
#  13  Valor de Compra    533246 non-null  float64
#  14  Unidade de Medida  802334 non-null  object
# ...

# %% [markdown]
# #### 2007

# %%
ca_2007_01 = pd.read_csv("rsc/ca-2007-01.csv", sep=';')

# %%
ca_2007_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla       Municipio  \
# 0             SE             SP        SOROCABA
# 1             SE             SP        SOROCABA
# 2             SE             SP        SOROCABA
# 3             SE             RJ  RIO DE JANEIRO
# 4             SE             RJ  RIO DE JANEIRO
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0013-38
# 4                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0013-38
#
#               Nome da Rua Numero Rua         Complemento          Bairro  \
# 0  RUA HUMBERTO DE CAMPOS        306                 NaN  JARDIM ZULMIRA
# 1  RUA HUMBERTO DE CAMPOS        306                 NaN  JARDIM ZULMIRA
# ...

# %%
ca_2007_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843679 entries, 0 to 843678
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     843679 non-null  object
#  1   Estado - Sigla     843679 non-null  object
#  2   Municipio          843679 non-null  object
#  3   Revenda            843679 non-null  object
#  4   CNPJ da Revenda    843679 non-null  object
#  5   Nome da Rua        843679 non-null  object
#  6   Numero Rua         843351 non-null  object
#  7   Complemento        230126 non-null  object
#  8   Bairro             841329 non-null  object
#  9   Cep                843679 non-null  object
#  10  Produto            843679 non-null  object
#  11  Data da Coleta     843679 non-null  object
#  12  Valor de Venda     843679 non-null  object
#  13  Valor de Compra    577294 non-null  object
#  14  Unidade de Medida  843679 non-null  object
# ...

# %%
ca_2007_01['Valor de Venda'] = ca_2007_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2007_01['Valor de Compra'] = ca_2007_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2007_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843679 entries, 0 to 843678
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     843679 non-null  object
#  1   Estado - Sigla     843679 non-null  object
#  2   Municipio          843679 non-null  object
#  3   Revenda            843679 non-null  object
#  4   CNPJ da Revenda    843679 non-null  object
#  5   Nome da Rua        843679 non-null  object
#  6   Numero Rua         843351 non-null  object
#  7   Complemento        230126 non-null  object
#  8   Bairro             841329 non-null  object
#  9   Cep                843679 non-null  object
#  10  Produto            843679 non-null  object
#  11  Data da Coleta     843679 non-null  object
#  12  Valor de Venda     843679 non-null  float64
#  13  Valor de Compra    577294 non-null  float64
#  14  Unidade de Medida  843679 non-null  object
# ...

# %%
ca_2007_02 = pd.read_csv("rsc/ca-2007-02.csv", sep=';')

# %%
ca_2007_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP    OSASCO
# 1             SE             SP    OSASCO
# 2             SE             SP    OSASCO
# 3             SE             SP  SOROCABA
# 4             SE             SP  SOROCABA
#
#                                              Revenda      CNPJ da Revenda  \
# 0                            AUTO POSTO ROMA II LTDA   67.507.673/0001-03
# 1                            AUTO POSTO ROMA II LTDA   67.507.673/0001-03
# 2                            AUTO POSTO ROMA II LTDA   67.507.673/0001-03
# 3  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 4  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0    AVENIDA JOAO ANDRADE    390/420           0   JARDIM VELOSO  06132-000
# 1    AVENIDA JOAO ANDRADE    390/420           0   JARDIM VELOSO  06132-000
# ...

# %%
ca_2007_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659632 entries, 0 to 659631
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     659632 non-null  object
#  1   Estado - Sigla     659632 non-null  object
#  2   Municipio          659632 non-null  object
#  3   Revenda            659632 non-null  object
#  4   CNPJ da Revenda    659632 non-null  object
#  5   Nome da Rua        659632 non-null  object
#  6   Numero Rua         659366 non-null  object
#  7   Complemento        177487 non-null  object
#  8   Bairro             657438 non-null  object
#  9   Cep                659632 non-null  object
#  10  Produto            659632 non-null  object
#  11  Data da Coleta     659632 non-null  object
#  12  Valor de Venda     659632 non-null  object
#  13  Valor de Compra    439763 non-null  object
#  14  Unidade de Medida  659632 non-null  object
# ...

# %%
ca_2007_02['Valor de Venda'] = ca_2007_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2007_02['Valor de Compra'] = ca_2007_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2007_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659632 entries, 0 to 659631
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     659632 non-null  object
#  1   Estado - Sigla     659632 non-null  object
#  2   Municipio          659632 non-null  object
#  3   Revenda            659632 non-null  object
#  4   CNPJ da Revenda    659632 non-null  object
#  5   Nome da Rua        659632 non-null  object
#  6   Numero Rua         659366 non-null  object
#  7   Complemento        177487 non-null  object
#  8   Bairro             657438 non-null  object
#  9   Cep                659632 non-null  object
#  10  Produto            659632 non-null  object
#  11  Data da Coleta     659632 non-null  object
#  12  Valor de Venda     659632 non-null  float64
#  13  Valor de Compra    439763 non-null  float64
#  14  Unidade de Medida  659632 non-null  object
# ...

# %% [markdown]
# #### 2008

# %%
ca_2008_01 = pd.read_csv("rsc/ca-2008-01.csv", sep=';')

# %%
ca_2008_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla                 Municipio  \
# 0             NE             BA                   ITABUNA
# 1             NE             BA                   ITABUNA
# 2             NE             BA                   ITABUNA
# 3             SE             MG  SAO SEBASTIAO DO PARAISO
# 4             SE             MG  SAO SEBASTIAO DO PARAISO
#
#                                      Revenda      CNPJ da Revenda  \
# 0  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 1  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 2  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 3               REDE DE POSTOS ZERO IV LTDA.   00.883.226/0001-88
# 4               REDE DE POSTOS ZERO IV LTDA.   00.883.226/0001-88
#
#             Nome da Rua Numero Rua  Complemento       Bairro        Cep  \
# 0        RODOVIA BR 101         SN  KM    503 5  MANOEL LEAO  45601-402
# ...

# %%
ca_2008_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636862 entries, 0 to 636861
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     636862 non-null  object
#  1   Estado - Sigla     636862 non-null  object
#  2   Municipio          636862 non-null  object
#  3   Revenda            636862 non-null  object
#  4   CNPJ da Revenda    636862 non-null  object
#  5   Nome da Rua        636862 non-null  object
#  6   Numero Rua         636543 non-null  object
#  7   Complemento        171799 non-null  object
#  8   Bairro             634671 non-null  object
#  9   Cep                636862 non-null  object
#  10  Produto            636862 non-null  object
#  11  Data da Coleta     636862 non-null  object
#  12  Valor de Venda     636862 non-null  object
#  13  Valor de Compra    386271 non-null  object
#  14  Unidade de Medida  636862 non-null  object
# ...

# %%
ca_2008_01['Valor de Venda'] = ca_2008_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2008_01['Valor de Compra'] = ca_2008_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2008_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636862 entries, 0 to 636861
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     636862 non-null  object
#  1   Estado - Sigla     636862 non-null  object
#  2   Municipio          636862 non-null  object
#  3   Revenda            636862 non-null  object
#  4   CNPJ da Revenda    636862 non-null  object
#  5   Nome da Rua        636862 non-null  object
#  6   Numero Rua         636543 non-null  object
#  7   Complemento        171799 non-null  object
#  8   Bairro             634671 non-null  object
#  9   Cep                636862 non-null  object
#  10  Produto            636862 non-null  object
#  11  Data da Coleta     636862 non-null  object
#  12  Valor de Venda     636862 non-null  float64
#  13  Valor de Compra    386271 non-null  float64
#  14  Unidade de Medida  636862 non-null  object
# ...

# %%
ca_2008_02 = pd.read_csv("rsc/ca-2008-02.csv", sep=';')

# %%
ca_2008_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio  \
# 0             SE             SP  ARARAQUARA
# 1             SE             SP  ARARAQUARA
# 2             SE             SP  ARARAQUARA
# 3             SE             SP   GUARULHOS
# 4             SE             SP   GUARULHOS
#
#                                   Revenda      CNPJ da Revenda  \
# 0  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 1  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 2  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 3                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
#
#                     Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 1  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 2  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# ...

# %%
ca_2008_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678557 entries, 0 to 678556
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     678557 non-null  object
#  1   Estado - Sigla     678557 non-null  object
#  2   Municipio          678557 non-null  object
#  3   Revenda            678557 non-null  object
#  4   CNPJ da Revenda    678557 non-null  object
#  5   Nome da Rua        678557 non-null  object
#  6   Numero Rua         678218 non-null  object
#  7   Complemento        182928 non-null  object
#  8   Bairro             676311 non-null  object
#  9   Cep                678557 non-null  object
#  10  Produto            678557 non-null  object
#  11  Data da Coleta     678557 non-null  object
#  12  Valor de Venda     678557 non-null  object
#  13  Valor de Compra    395809 non-null  object
#  14  Unidade de Medida  678557 non-null  object
# ...

# %%
ca_2008_02['Valor de Venda'] = ca_2008_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2008_02['Valor de Compra'] = ca_2008_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2008_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678557 entries, 0 to 678556
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     678557 non-null  object
#  1   Estado - Sigla     678557 non-null  object
#  2   Municipio          678557 non-null  object
#  3   Revenda            678557 non-null  object
#  4   CNPJ da Revenda    678557 non-null  object
#  5   Nome da Rua        678557 non-null  object
#  6   Numero Rua         678218 non-null  object
#  7   Complemento        182928 non-null  object
#  8   Bairro             676311 non-null  object
#  9   Cep                678557 non-null  object
#  10  Produto            678557 non-null  object
#  11  Data da Coleta     678557 non-null  object
#  12  Valor de Venda     678557 non-null  float64
#  13  Valor de Compra    395809 non-null  float64
#  14  Unidade de Medida  678557 non-null  object
# ...

# %% [markdown]
# #### 2009

# %%
ca_2009_01 = pd.read_csv("rsc/ca-2009-01.csv", sep=';')

# %%
ca_2009_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP    OSASCO
# 1             SE             SP    OSASCO
# 2             SE             SP    OSASCO
# 3             SE             SP  SOROCABA
# 4             SE             SP  SOROCABA
#
#                                              Revenda      CNPJ da Revenda  \
# 0                            AUTO POSTO ROMA II LTDA   67.507.673/0001-03
# 1                            AUTO POSTO ROMA II LTDA   67.507.673/0001-03
# 2                            AUTO POSTO ROMA II LTDA   67.507.673/0001-03
# 3  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 4  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0    AVENIDA JOAO ANDRADE    390/420           0   JARDIM VELOSO  06132-000
# 1    AVENIDA JOAO ANDRADE    390/420           0   JARDIM VELOSO  06132-000
# ...

# %%
ca_2009_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644873 entries, 0 to 644872
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     644873 non-null  object
#  1   Estado - Sigla     644873 non-null  object
#  2   Municipio          644873 non-null  object
#  3   Revenda            644873 non-null  object
#  4   CNPJ da Revenda    644873 non-null  object
#  5   Nome da Rua        644873 non-null  object
#  6   Numero Rua         644604 non-null  object
#  7   Complemento        172936 non-null  object
#  8   Bairro             642736 non-null  object
#  9   Cep                644873 non-null  object
#  10  Produto            644873 non-null  object
#  11  Data da Coleta     644873 non-null  object
#  12  Valor de Venda     644873 non-null  object
#  13  Valor de Compra    364309 non-null  object
#  14  Unidade de Medida  644873 non-null  object
# ...

# %%
ca_2009_01['Valor de Venda'] = ca_2009_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2009_01['Valor de Compra'] = ca_2009_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2009_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644873 entries, 0 to 644872
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     644873 non-null  object
#  1   Estado - Sigla     644873 non-null  object
#  2   Municipio          644873 non-null  object
#  3   Revenda            644873 non-null  object
#  4   CNPJ da Revenda    644873 non-null  object
#  5   Nome da Rua        644873 non-null  object
#  6   Numero Rua         644604 non-null  object
#  7   Complemento        172936 non-null  object
#  8   Bairro             642736 non-null  object
#  9   Cep                644873 non-null  object
#  10  Produto            644873 non-null  object
#  11  Data da Coleta     644873 non-null  object
#  12  Valor de Venda     644873 non-null  float64
#  13  Valor de Compra    364309 non-null  float64
#  14  Unidade de Medida  644873 non-null  object
# ...

# %%
ca_2009_02 = pd.read_csv("rsc/ca-2009-02.csv", sep=';')

# %%
ca_2009_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla     Municipio  \
# 0             NE             BA       ITABUNA
# 1             NE             BA       ITABUNA
# 2             NE             BA       ITABUNA
# 3              S             RS  PORTO ALEGRE
# 4              S             RS  PORTO ALEGRE
#
#                                      Revenda      CNPJ da Revenda  \
# 0  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 1  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 2  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 3          COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14
# 4          COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14
#
#          Nome da Rua Numero Rua  Complemento       Bairro        Cep  \
# 0     RODOVIA BR 101         SN  KM    503 5  MANOEL LEAO  45601-402
# 1     RODOVIA BR 101         SN  KM    503 5  MANOEL LEAO  45601-402
# 2     RODOVIA BR 101         SN  KM    503 5  MANOEL LEAO  45601-402
# ...

# %%
ca_2009_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485891 entries, 0 to 485890
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     485891 non-null  object
#  1   Estado - Sigla     485891 non-null  object
#  2   Municipio          485891 non-null  object
#  3   Revenda            485891 non-null  object
#  4   CNPJ da Revenda    485891 non-null  object
#  5   Nome da Rua        485891 non-null  object
#  6   Numero Rua         485702 non-null  object
#  7   Complemento        131553 non-null  object
#  8   Bairro             484419 non-null  object
#  9   Cep                485891 non-null  object
#  10  Produto            485891 non-null  object
#  11  Data da Coleta     485891 non-null  object
#  12  Valor de Venda     485891 non-null  object
#  13  Valor de Compra    280129 non-null  object
#  14  Unidade de Medida  485891 non-null  object
# ...

# %%
ca_2009_02['Valor de Venda'] = ca_2009_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2009_02['Valor de Compra'] = ca_2009_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2009_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485891 entries, 0 to 485890
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     485891 non-null  object
#  1   Estado - Sigla     485891 non-null  object
#  2   Municipio          485891 non-null  object
#  3   Revenda            485891 non-null  object
#  4   CNPJ da Revenda    485891 non-null  object
#  5   Nome da Rua        485891 non-null  object
#  6   Numero Rua         485702 non-null  object
#  7   Complemento        131553 non-null  object
#  8   Bairro             484419 non-null  object
#  9   Cep                485891 non-null  object
#  10  Produto            485891 non-null  object
#  11  Data da Coleta     485891 non-null  object
#  12  Valor de Venda     485891 non-null  float64
#  13  Valor de Compra    280129 non-null  float64
#  14  Unidade de Medida  485891 non-null  object
# ...

# %% [markdown]
# #### 2010

# %%
ca_2010_01 = pd.read_csv("rsc/ca-2010-01.csv", sep=';')

# %%
ca_2010_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP  GUARULHOS
# 4             NE             BA    ITABUNA
#
#                                      Revenda      CNPJ da Revenda  \
# 0                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                   AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#                 Nome da Rua Numero Rua          Complemento       Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ   BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ   BONSUCESSO
# 2  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ   BONSUCESSO
# ...

# %%
ca_2010_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628516 entries, 0 to 628515
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     628516 non-null  object
#  1   Estado - Sigla     628516 non-null  object
#  2   Municipio          628516 non-null  object
#  3   Revenda            628516 non-null  object
#  4   CNPJ da Revenda    628516 non-null  object
#  5   Nome da Rua        628516 non-null  object
#  6   Numero Rua         628166 non-null  object
#  7   Complemento        171475 non-null  object
#  8   Bairro             626448 non-null  object
#  9   Cep                628516 non-null  object
#  10  Produto            628516 non-null  object
#  11  Data da Coleta     628516 non-null  object
#  12  Valor de Venda     628516 non-null  object
#  13  Valor de Compra    321406 non-null  object
#  14  Unidade de Medida  628516 non-null  object
# ...

# %%
ca_2010_01['Valor de Venda'] = ca_2010_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2010_01['Valor de Compra'] = ca_2010_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2010_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628516 entries, 0 to 628515
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     628516 non-null  object
#  1   Estado - Sigla     628516 non-null  object
#  2   Municipio          628516 non-null  object
#  3   Revenda            628516 non-null  object
#  4   CNPJ da Revenda    628516 non-null  object
#  5   Nome da Rua        628516 non-null  object
#  6   Numero Rua         628166 non-null  object
#  7   Complemento        171475 non-null  object
#  8   Bairro             626448 non-null  object
#  9   Cep                628516 non-null  object
#  10  Produto            628516 non-null  object
#  11  Data da Coleta     628516 non-null  object
#  12  Valor de Venda     628516 non-null  float64
#  13  Valor de Compra    321406 non-null  float64
#  14  Unidade de Medida  628516 non-null  object
# ...

# %%
ca_2010_02 = pd.read_csv("rsc/ca-2010-02.csv", sep=';')

# %%
ca_2010_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla     Municipio  \
# 0              S             RS  PORTO ALEGRE
# 1              S             RS  PORTO ALEGRE
# 2              S             RS  PORTO ALEGRE
# 3             SE             MG     BARBACENA
# 4             SE             MG   SANTA LUZIA
#
#                              Revenda      CNPJ da Revenda        Nome da Rua  \
# 0  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14  RUA EDUARDO PRADO
# 1  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14  RUA EDUARDO PRADO
# 2  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14  RUA EDUARDO PRADO
# 3                    GNV CABANA LTDA   04.760.870/0001-10     RODOVIA BR 040
# 4                POSTO LUZIENSE LTDA   03.330.723/0001-47       RUA ALVORADA
#
#   Numero Rua            Complemento        Bairro        Cep   Produto  \
# 0        415              CAVALHADA     CAVALHADA  91751-000  GASOLINA
# 1        415              CAVALHADA     CAVALHADA  91751-000    ETANOL
# ...

# %%
ca_2010_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645339 entries, 0 to 645338
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     645339 non-null  object
#  1   Estado - Sigla     645339 non-null  object
#  2   Municipio          645339 non-null  object
#  3   Revenda            645339 non-null  object
#  4   CNPJ da Revenda    645339 non-null  object
#  5   Nome da Rua        645339 non-null  object
#  6   Numero Rua         644919 non-null  object
#  7   Complemento        171704 non-null  object
#  8   Bairro             643206 non-null  object
#  9   Cep                645339 non-null  object
#  10  Produto            645339 non-null  object
#  11  Data da Coleta     645339 non-null  object
#  12  Valor de Venda     645339 non-null  object
#  13  Valor de Compra    310272 non-null  object
#  14  Unidade de Medida  645339 non-null  object
# ...

# %%
ca_2010_02['Valor de Venda'] = ca_2010_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2010_02['Valor de Compra'] = ca_2010_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2010_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645339 entries, 0 to 645338
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     645339 non-null  object
#  1   Estado - Sigla     645339 non-null  object
#  2   Municipio          645339 non-null  object
#  3   Revenda            645339 non-null  object
#  4   CNPJ da Revenda    645339 non-null  object
#  5   Nome da Rua        645339 non-null  object
#  6   Numero Rua         644919 non-null  object
#  7   Complemento        171704 non-null  object
#  8   Bairro             643206 non-null  object
#  9   Cep                645339 non-null  object
#  10  Produto            645339 non-null  object
#  11  Data da Coleta     645339 non-null  object
#  12  Valor de Venda     645339 non-null  float64
#  13  Valor de Compra    310272 non-null  float64
#  14  Unidade de Medida  645339 non-null  object
# ...

# %% [markdown]
# #### 2011

# %%
ca_2011_01 = pd.read_csv("rsc/ca-2011-01.csv", sep=';')

# %%
ca_2011_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio  \
# 0             SE             SP  ARARAQUARA
# 1             SE             SP  ARARAQUARA
# 2             SE             SP  ARARAQUARA
# 3             SE             SP   GUARULHOS
# 4             SE             SP   GUARULHOS
#
#                                   Revenda      CNPJ da Revenda  \
# 0  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 1  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 2  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 3                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
#
#                     Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 1  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 2  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# ...

# %%
ca_2011_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649693 entries, 0 to 649692
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     649693 non-null  object
#  1   Estado - Sigla     649693 non-null  object
#  2   Municipio          649693 non-null  object
#  3   Revenda            649693 non-null  object
#  4   CNPJ da Revenda    649693 non-null  object
#  5   Nome da Rua        649693 non-null  object
#  6   Numero Rua         649335 non-null  object
#  7   Complemento        173123 non-null  object
#  8   Bairro             647412 non-null  object
#  9   Cep                649693 non-null  object
#  10  Produto            649693 non-null  object
#  11  Data da Coleta     649693 non-null  object
#  12  Valor de Venda     649693 non-null  object
#  13  Valor de Compra    280130 non-null  object
#  14  Unidade de Medida  649693 non-null  object
# ...

# %%
ca_2011_01['Valor de Venda'] = ca_2011_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2011_01['Valor de Compra'] = ca_2011_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2011_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649693 entries, 0 to 649692
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     649693 non-null  object
#  1   Estado - Sigla     649693 non-null  object
#  2   Municipio          649693 non-null  object
#  3   Revenda            649693 non-null  object
#  4   CNPJ da Revenda    649693 non-null  object
#  5   Nome da Rua        649693 non-null  object
#  6   Numero Rua         649335 non-null  object
#  7   Complemento        173123 non-null  object
#  8   Bairro             647412 non-null  object
#  9   Cep                649693 non-null  object
#  10  Produto            649693 non-null  object
#  11  Data da Coleta     649693 non-null  object
#  12  Valor de Venda     649693 non-null  float64
#  13  Valor de Compra    280130 non-null  float64
#  14  Unidade de Medida  649693 non-null  object
# ...

# %%
ca_2011_02 = pd.read_csv("rsc/ca-2011-02.csv", sep=';')

# %%
ca_2011_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0              S             RS    CANOAS
# 1              S             RS    CANOAS
# 2              S             RS    CANOAS
# 3             NE             BA   ITABUNA
# 4             NE             BA   ITABUNA
#
#                                        Revenda      CNPJ da Revenda  \
# 0  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 1  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 2  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 3    LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4    LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#                 Nome da Rua Numero Rua  Complemento       Bairro        Cep  \
# 0  AVENIDA GUILHERME SCHELL       6340          NaN       CENTRO  92310-000
# 1  AVENIDA GUILHERME SCHELL       6340          NaN       CENTRO  92310-000
# ...

# %%
ca_2011_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650008 entries, 0 to 650007
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     650008 non-null  object
#  1   Estado - Sigla     650008 non-null  object
#  2   Municipio          650008 non-null  object
#  3   Revenda            650008 non-null  object
#  4   CNPJ da Revenda    650008 non-null  object
#  5   Nome da Rua        650008 non-null  object
#  6   Numero Rua         649694 non-null  object
#  7   Complemento        172343 non-null  object
#  8   Bairro             647920 non-null  object
#  9   Cep                650008 non-null  object
#  10  Produto            650008 non-null  object
#  11  Data da Coleta     650008 non-null  object
#  12  Valor de Venda     650008 non-null  object
#  13  Valor de Compra    271564 non-null  object
#  14  Unidade de Medida  650008 non-null  object
# ...

# %%
ca_2011_02['Valor de Venda'] = ca_2011_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2011_02['Valor de Compra'] = ca_2011_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2011_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650008 entries, 0 to 650007
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     650008 non-null  object
#  1   Estado - Sigla     650008 non-null  object
#  2   Municipio          650008 non-null  object
#  3   Revenda            650008 non-null  object
#  4   CNPJ da Revenda    650008 non-null  object
#  5   Nome da Rua        650008 non-null  object
#  6   Numero Rua         649694 non-null  object
#  7   Complemento        172343 non-null  object
#  8   Bairro             647920 non-null  object
#  9   Cep                650008 non-null  object
#  10  Produto            650008 non-null  object
#  11  Data da Coleta     650008 non-null  object
#  12  Valor de Venda     650008 non-null  float64
#  13  Valor de Compra    271564 non-null  float64
#  14  Unidade de Medida  650008 non-null  object
# ...

# %% [markdown]
# #### 2012

# %%
ca_2012_01 = pd.read_csv("rsc/ca-2012-01.csv", sep=';')

# %%
ca_2012_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             CO             DF   BRASILIA
# 4             CO             DF   BRASILIA
#
#                                 Revenda      CNPJ da Revenda  \
# 0              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3  GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.   00.603.738/0001-43
# 4  GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.   00.603.738/0001-43
#
#                                    Nome da Rua Numero Rua  \
# 0                     RODOVIA PRESIDENTE DUTRA        S/N
# 1                     RODOVIA PRESIDENTE DUTRA        S/N
# 2                     RODOVIA PRESIDENTE DUTRA        S/N
# 3  QI-QUADRA INTERNA 18  LOTES 47, 49, 51 E 53        S/N
# ...

# %%
ca_2012_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662246 entries, 0 to 662245
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     662246 non-null  object
#  1   Estado - Sigla     662246 non-null  object
#  2   Municipio          662246 non-null  object
#  3   Revenda            662246 non-null  object
#  4   CNPJ da Revenda    662246 non-null  object
#  5   Nome da Rua        662246 non-null  object
#  6   Numero Rua         661873 non-null  object
#  7   Complemento        174384 non-null  object
#  8   Bairro             660174 non-null  object
#  9   Cep                662246 non-null  object
#  10  Produto            662246 non-null  object
#  11  Data da Coleta     662246 non-null  object
#  12  Valor de Venda     662246 non-null  object
#  13  Valor de Compra    283708 non-null  object
#  14  Unidade de Medida  662246 non-null  object
# ...

# %%
ca_2012_01['Valor de Venda'] = ca_2012_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2012_01['Valor de Compra'] = ca_2012_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2012_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662246 entries, 0 to 662245
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     662246 non-null  object
#  1   Estado - Sigla     662246 non-null  object
#  2   Municipio          662246 non-null  object
#  3   Revenda            662246 non-null  object
#  4   CNPJ da Revenda    662246 non-null  object
#  5   Nome da Rua        662246 non-null  object
#  6   Numero Rua         661873 non-null  object
#  7   Complemento        174384 non-null  object
#  8   Bairro             660174 non-null  object
#  9   Cep                662246 non-null  object
#  10  Produto            662246 non-null  object
#  11  Data da Coleta     662246 non-null  object
#  12  Valor de Venda     662246 non-null  float64
#  13  Valor de Compra    283708 non-null  float64
#  14  Unidade de Medida  662246 non-null  object
# ...

# %%
ca_2012_02 = pd.read_csv("rsc/ca-2012-02.csv", sep=';')

# %%
ca_2012_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla    Municipio  \
# 0             NE             BA      ITABUNA
# 1             NE             BA      ITABUNA
# 2             NE             BA      ITABUNA
# 3             NE             BA      ITABUNA
# 4              S             PR  PATO BRANCO
#
#                                      Revenda      CNPJ da Revenda  \
# 0  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 1  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 2  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 3  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4                       SANTOS & MERLO LTDA.   79.854.667/0001-01
#
#       Nome da Rua Numero Rua  Complemento       Bairro        Cep     Produto  \
# 0  RODOVIA BR 101         SN  KM    503 5  MANOEL LEAO  45601-402    GASOLINA
# 1  RODOVIA BR 101         SN  KM    503 5  MANOEL LEAO  45601-402      ETANOL
# ...

# %%
ca_2012_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672257 entries, 0 to 672256
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     672257 non-null  object
#  1   Estado - Sigla     672257 non-null  object
#  2   Municipio          672257 non-null  object
#  3   Revenda            672257 non-null  object
#  4   CNPJ da Revenda    672257 non-null  object
#  5   Nome da Rua        672257 non-null  object
#  6   Numero Rua         671891 non-null  object
#  7   Complemento        176801 non-null  object
#  8   Bairro             670009 non-null  object
#  9   Cep                672257 non-null  object
#  10  Produto            672257 non-null  object
#  11  Data da Coleta     672257 non-null  object
#  12  Valor de Venda     672257 non-null  object
#  13  Valor de Compra    304993 non-null  object
#  14  Unidade de Medida  672257 non-null  object
# ...

# %%
ca_2012_02['Valor de Venda'] = ca_2012_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2012_02['Valor de Compra'] = ca_2012_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2012_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672257 entries, 0 to 672256
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     672257 non-null  object
#  1   Estado - Sigla     672257 non-null  object
#  2   Municipio          672257 non-null  object
#  3   Revenda            672257 non-null  object
#  4   CNPJ da Revenda    672257 non-null  object
#  5   Nome da Rua        672257 non-null  object
#  6   Numero Rua         671891 non-null  object
#  7   Complemento        176801 non-null  object
#  8   Bairro             670009 non-null  object
#  9   Cep                672257 non-null  object
#  10  Produto            672257 non-null  object
#  11  Data da Coleta     672257 non-null  object
#  12  Valor de Venda     672257 non-null  float64
#  13  Valor de Compra    304993 non-null  float64
#  14  Unidade de Medida  672257 non-null  object
# ...

# %% [markdown]
# #### 2013

# %%
ca_2013_01 = pd.read_csv("rsc/ca-2013-01.csv", sep=';')

# %%
ca_2013_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP  GUARULHOS
# 4             CO             DF   BRASILIA
#
#                                 Revenda      CNPJ da Revenda  \
# 0              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3              AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.   00.603.738/0001-43
#
#                                    Nome da Rua Numero Rua  \
# 0                     RODOVIA PRESIDENTE DUTRA        S/N
# 1                     RODOVIA PRESIDENTE DUTRA        S/N
# 2                     RODOVIA PRESIDENTE DUTRA        S/N
# 3                     RODOVIA PRESIDENTE DUTRA        S/N
# ...

# %%
ca_2013_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664530 entries, 0 to 664529
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     664530 non-null  object
#  1   Estado - Sigla     664530 non-null  object
#  2   Municipio          664530 non-null  object
#  3   Revenda            664530 non-null  object
#  4   CNPJ da Revenda    664530 non-null  object
#  5   Nome da Rua        664530 non-null  object
#  6   Numero Rua         664101 non-null  object
#  7   Complemento        173830 non-null  object
#  8   Bairro             662184 non-null  object
#  9   Cep                664530 non-null  object
#  10  Produto            664530 non-null  object
#  11  Data da Coleta     664530 non-null  object
#  12  Valor de Venda     664530 non-null  object
#  13  Valor de Compra    293307 non-null  object
#  14  Unidade de Medida  664530 non-null  object
# ...

# %%
ca_2013_01['Valor de Venda'] = ca_2013_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2013_01['Valor de Compra'] = ca_2013_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2013_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664530 entries, 0 to 664529
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     664530 non-null  object
#  1   Estado - Sigla     664530 non-null  object
#  2   Municipio          664530 non-null  object
#  3   Revenda            664530 non-null  object
#  4   CNPJ da Revenda    664530 non-null  object
#  5   Nome da Rua        664530 non-null  object
#  6   Numero Rua         664101 non-null  object
#  7   Complemento        173830 non-null  object
#  8   Bairro             662184 non-null  object
#  9   Cep                664530 non-null  object
#  10  Produto            664530 non-null  object
#  11  Data da Coleta     664530 non-null  object
#  12  Valor de Venda     664530 non-null  float64
#  13  Valor de Compra    293307 non-null  float64
#  14  Unidade de Medida  664530 non-null  object
# ...

# %%
ca_2013_02 = pd.read_csv("rsc/ca-2013-02.csv", sep=';')

# %%
ca_2013_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla    Municipio  \
# 0             NE             BA      ITABUNA
# 1             NE             BA      ITABUNA
# 2             NE             BA      ITABUNA
# 3              S             RS  SANTA MARIA
# 4              S             RS  SANTA MARIA
#
#                                      Revenda      CNPJ da Revenda  \
# 0  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 1  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 2  LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 3  SANTA LUCIA COMERCIO E PAVIMENTACOES LTDA   87.305.868/0001-88
# 4  SANTA LUCIA COMERCIO E PAVIMENTACOES LTDA   87.305.868/0001-88
#
#       Nome da Rua Numero Rua  Complemento        Bairro        Cep  \
# 0  RODOVIA BR 101         SN  KM    503 5   MANOEL LEAO  45601-402
# 1  RODOVIA BR 101         SN  KM    503 5   MANOEL LEAO  45601-402
# 2  RODOVIA BR 101         SN  KM    503 5   MANOEL LEAO  45601-402
# ...

# %%
ca_2013_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699372 entries, 0 to 699371
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     699372 non-null  object
#  1   Estado - Sigla     699372 non-null  object
#  2   Municipio          699372 non-null  object
#  3   Revenda            699372 non-null  object
#  4   CNPJ da Revenda    699372 non-null  object
#  5   Nome da Rua        699372 non-null  object
#  6   Numero Rua         698917 non-null  object
#  7   Complemento        184644 non-null  object
#  8   Bairro             696923 non-null  object
#  9   Cep                699372 non-null  object
#  10  Produto            699372 non-null  object
#  11  Data da Coleta     699372 non-null  object
#  12  Valor de Venda     699372 non-null  object
#  13  Valor de Compra    302797 non-null  object
#  14  Unidade de Medida  699372 non-null  object
# ...

# %%
ca_2013_02['Valor de Venda'] = ca_2013_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2013_02['Valor de Compra'] = ca_2013_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2013_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699372 entries, 0 to 699371
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     699372 non-null  object
#  1   Estado - Sigla     699372 non-null  object
#  2   Municipio          699372 non-null  object
#  3   Revenda            699372 non-null  object
#  4   CNPJ da Revenda    699372 non-null  object
#  5   Nome da Rua        699372 non-null  object
#  6   Numero Rua         698917 non-null  object
#  7   Complemento        184644 non-null  object
#  8   Bairro             696923 non-null  object
#  9   Cep                699372 non-null  object
#  10  Produto            699372 non-null  object
#  11  Data da Coleta     699372 non-null  object
#  12  Valor de Venda     699372 non-null  float64
#  13  Valor de Compra    302797 non-null  float64
#  14  Unidade de Medida  699372 non-null  object
# ...

# %% [markdown]
# #### 2014

# %%
ca_2014_01 = pd.read_csv("rsc/ca-2014-01.csv", sep=';')

# %%
ca_2014_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio                   Revenda  \
# 0             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 1             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 2             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 3             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 4             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
#
#        CNPJ da Revenda               Nome da Rua Numero Rua  \
# 0   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 1   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 2   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 3   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 4   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
#
#            Complemento      Bairro        Cep     Produto Data da Coleta  \
# 0  KM 210,5-SENT SP/RJ  BONSUCESSO  07178-580    GASOLINA     02/01/2014
# ...

# %%
ca_2014_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473636 entries, 0 to 473635
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     473636 non-null  object
#  1   Estado - Sigla     473636 non-null  object
#  2   Municipio          473636 non-null  object
#  3   Revenda            473636 non-null  object
#  4   CNPJ da Revenda    473636 non-null  object
#  5   Nome da Rua        473636 non-null  object
#  6   Numero Rua         473412 non-null  object
#  7   Complemento        125453 non-null  object
#  8   Bairro             471933 non-null  object
#  9   Cep                473636 non-null  object
#  10  Produto            473636 non-null  object
#  11  Data da Coleta     473635 non-null  object
#  12  Valor de Venda     473635 non-null  object
#  13  Valor de Compra    197685 non-null  object
#  14  Unidade de Medida  473635 non-null  object
# ...

# %%
ca_2014_01['Valor de Venda'] = ca_2014_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2014_01['Valor de Compra'] = ca_2014_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2014_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473636 entries, 0 to 473635
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     473636 non-null  object
#  1   Estado - Sigla     473636 non-null  object
#  2   Municipio          473636 non-null  object
#  3   Revenda            473636 non-null  object
#  4   CNPJ da Revenda    473636 non-null  object
#  5   Nome da Rua        473636 non-null  object
#  6   Numero Rua         473412 non-null  object
#  7   Complemento        125453 non-null  object
#  8   Bairro             471933 non-null  object
#  9   Cep                473636 non-null  object
#  10  Produto            473636 non-null  object
#  11  Data da Coleta     473635 non-null  object
#  12  Valor de Venda     473635 non-null  float64
#  13  Valor de Compra    197685 non-null  float64
#  14  Unidade de Medida  473635 non-null  object
# ...

# %%
ca_2014_02 = pd.read_csv("rsc/ca-2014-02.csv", sep=';')

# %%
ca_2014_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla    Municipio  \
# 0             SE             SP     SOROCABA
# 1             SE             SP     SOROCABA
# 2             SE             SP     SOROCABA
# 3              S             PR  PATO BRANCO
# 4              S             PR  PATO BRANCO
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                               SANTOS & MERLO LTDA.   79.854.667/0001-01
# 4                               SANTOS & MERLO LTDA.   79.854.667/0001-01
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
ca_2014_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723088 entries, 0 to 723087
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     723088 non-null  object
#  1   Estado - Sigla     723088 non-null  object
#  2   Municipio          723088 non-null  object
#  3   Revenda            723088 non-null  object
#  4   CNPJ da Revenda    723088 non-null  object
#  5   Nome da Rua        723088 non-null  object
#  6   Numero Rua         722776 non-null  object
#  7   Complemento        188849 non-null  object
#  8   Bairro             720559 non-null  object
#  9   Cep                723088 non-null  object
#  10  Produto            723088 non-null  object
#  11  Data da Coleta     723088 non-null  object
#  12  Valor de Venda     723088 non-null  object
#  13  Valor de Compra    291490 non-null  object
#  14  Unidade de Medida  723088 non-null  object
# ...

# %%
ca_2014_02['Valor de Venda'] = ca_2014_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2014_02['Valor de Compra'] = ca_2014_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2014_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723088 entries, 0 to 723087
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     723088 non-null  object
#  1   Estado - Sigla     723088 non-null  object
#  2   Municipio          723088 non-null  object
#  3   Revenda            723088 non-null  object
#  4   CNPJ da Revenda    723088 non-null  object
#  5   Nome da Rua        723088 non-null  object
#  6   Numero Rua         722776 non-null  object
#  7   Complemento        188849 non-null  object
#  8   Bairro             720559 non-null  object
#  9   Cep                723088 non-null  object
#  10  Produto            723088 non-null  object
#  11  Data da Coleta     723088 non-null  object
#  12  Valor de Venda     723088 non-null  float64
#  13  Valor de Compra    291490 non-null  float64
#  14  Unidade de Medida  723088 non-null  object
# ...

# %% [markdown]
# #### 2015

# %%
ca_2015_01 = pd.read_csv("rsc/ca-2015-01.csv", sep=';')

# %%
ca_2015_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla         Municipio  \
# 0              N             AC  SENADOR GUIOMARD
# 1              N             AC  SENADOR GUIOMARD
# 2              N             AC  SENADOR GUIOMARD
# 3              N             AC  SENADOR GUIOMARD
# 4              N             AC  SENADOR GUIOMARD
#
#                        Revenda      CNPJ da Revenda             Nome da Rua  \
# 0  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 1  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 2  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 3  AUTO POSTO SANTA RITA LTDA.   07.600.665/0001-85  AVENIDA CASTELO BRANCO
# 4      AUTO POSTO QUINARI LTDA   10.209.732/0001-40  AVENIDA CASTELO BRANCO
#
#   Numero Rua Complemento   Bairro        Cep     Produto Data da Coleta  \
# 0        122         NaN  TRIUNFO  69925-000    GASOLINA     01/01/2015
# ...

# %%
ca_2015_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696774 entries, 0 to 696773
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     696774 non-null  object
#  1   Estado - Sigla     696774 non-null  object
#  2   Municipio          696774 non-null  object
#  3   Revenda            696774 non-null  object
#  4   CNPJ da Revenda    696774 non-null  object
#  5   Nome da Rua        696774 non-null  object
#  6   Numero Rua         696341 non-null  object
#  7   Complemento        181073 non-null  object
#  8   Bairro             694242 non-null  object
#  9   Cep                696774 non-null  object
#  10  Produto            696774 non-null  object
#  11  Data da Coleta     696774 non-null  object
#  12  Valor de Venda     696774 non-null  object
#  13  Valor de Compra    266617 non-null  object
#  14  Unidade de Medida  696774 non-null  object
# ...

# %%
ca_2015_01['Valor de Venda'] = ca_2015_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2015_01['Valor de Compra'] = ca_2015_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2015_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696774 entries, 0 to 696773
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     696774 non-null  object
#  1   Estado - Sigla     696774 non-null  object
#  2   Municipio          696774 non-null  object
#  3   Revenda            696774 non-null  object
#  4   CNPJ da Revenda    696774 non-null  object
#  5   Nome da Rua        696774 non-null  object
#  6   Numero Rua         696341 non-null  object
#  7   Complemento        181073 non-null  object
#  8   Bairro             694242 non-null  object
#  9   Cep                696774 non-null  object
#  10  Produto            696774 non-null  object
#  11  Data da Coleta     696774 non-null  object
#  12  Valor de Venda     696774 non-null  float64
#  13  Valor de Compra    266617 non-null  float64
#  14  Unidade de Medida  696774 non-null  object
# ...

# %%
ca_2015_02 = pd.read_csv("rsc/ca-2015-02.csv", sep=';')

# %%
ca_2015_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla    Municipio                       Revenda  \
# 0             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 1             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 2             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 3             NE             BA     SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
# 4              S             PR  PATO BRANCO          SANTOS & MERLO LTDA.
#
#        CNPJ da Revenda        Nome da Rua Numero Rua Complemento  Bairro  \
# 0   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 1   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 2   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 3   34.274.233/0015-08  RUA EDISTIO PONDE        474         NaN   STIEP
# 4   79.854.667/0001-01      RUA TOCANTINS       2535         NaN  CENTRO
#
#          Cep     Produto Data da Coleta Valor de Venda Valor de Compra  \
# ...

# %%
ca_2015_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410974 entries, 0 to 410973
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     410974 non-null  object
#  1   Estado - Sigla     410974 non-null  object
#  2   Municipio          410974 non-null  object
#  3   Revenda            410974 non-null  object
#  4   CNPJ da Revenda    410974 non-null  object
#  5   Nome da Rua        410974 non-null  object
#  6   Numero Rua         410697 non-null  object
#  7   Complemento        104189 non-null  object
#  8   Bairro             409723 non-null  object
#  9   Cep                410974 non-null  object
#  10  Produto            410974 non-null  object
#  11  Data da Coleta     410974 non-null  object
#  12  Valor de Venda     410974 non-null  object
#  13  Valor de Compra    164426 non-null  object
#  14  Unidade de Medida  410974 non-null  object
# ...

# %%
ca_2015_02['Valor de Venda'] = ca_2015_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2015_02['Valor de Compra'] = ca_2015_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2015_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410974 entries, 0 to 410973
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     410974 non-null  object
#  1   Estado - Sigla     410974 non-null  object
#  2   Municipio          410974 non-null  object
#  3   Revenda            410974 non-null  object
#  4   CNPJ da Revenda    410974 non-null  object
#  5   Nome da Rua        410974 non-null  object
#  6   Numero Rua         410697 non-null  object
#  7   Complemento        104189 non-null  object
#  8   Bairro             409723 non-null  object
#  9   Cep                410974 non-null  object
#  10  Produto            410974 non-null  object
#  11  Data da Coleta     410974 non-null  object
#  12  Valor de Venda     410974 non-null  float64
#  13  Valor de Compra    164426 non-null  float64
#  14  Unidade de Medida  410974 non-null  object
# ...

# %% [markdown]
# #### 2016

# %%
ca_2016_01 = pd.read_csv("rsc/ca-2016-01.csv", sep=';')

# %%
ca_2016_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP  SOROCABA
# 1             SE             SP  SOROCABA
# 2             SE             SP  SOROCABA
# 3             NE             BA   ITABUNA
# 4             NE             BA   ITABUNA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3          LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4          LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#               Nome da Rua Numero Rua  Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306          NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306          NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
ca_2016_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486897 entries, 0 to 486896
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     486897 non-null  object
#  1   Estado - Sigla     486897 non-null  object
#  2   Municipio          486897 non-null  object
#  3   Revenda            486897 non-null  object
#  4   CNPJ da Revenda    486897 non-null  object
#  5   Nome da Rua        486897 non-null  object
#  6   Numero Rua         486619 non-null  object
#  7   Complemento        124413 non-null  object
#  8   Bairro             485102 non-null  object
#  9   Cep                486897 non-null  object
#  10  Produto            486897 non-null  object
#  11  Data da Coleta     486897 non-null  object
#  12  Valor de Venda     486897 non-null  object
#  13  Valor de Compra    191504 non-null  object
#  14  Unidade de Medida  486897 non-null  object
# ...

# %%
ca_2016_01['Valor de Venda'] = ca_2016_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2016_01['Valor de Compra'] = ca_2016_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2016_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486897 entries, 0 to 486896
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     486897 non-null  object
#  1   Estado - Sigla     486897 non-null  object
#  2   Municipio          486897 non-null  object
#  3   Revenda            486897 non-null  object
#  4   CNPJ da Revenda    486897 non-null  object
#  5   Nome da Rua        486897 non-null  object
#  6   Numero Rua         486619 non-null  object
#  7   Complemento        124413 non-null  object
#  8   Bairro             485102 non-null  object
#  9   Cep                486897 non-null  object
#  10  Produto            486897 non-null  object
#  11  Data da Coleta     486897 non-null  object
#  12  Valor de Venda     486897 non-null  float64
#  13  Valor de Compra    191504 non-null  float64
#  14  Unidade de Medida  486897 non-null  object
# ...

# %%
ca_2016_02 = pd.read_csv("rsc/ca-2016-02.csv", sep=';')

# %%
ca_2016_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP  SOROCABA
# 1             SE             SP  SOROCABA
# 2             SE             SP  SOROCABA
# 3              S             RS    CANOAS
# 4              S             RS    CANOAS
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3        METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 4        METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0    RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1    RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
ca_2016_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488960 entries, 0 to 488959
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     488960 non-null  object
#  1   Estado - Sigla     488960 non-null  object
#  2   Municipio          488960 non-null  object
#  3   Revenda            488960 non-null  object
#  4   CNPJ da Revenda    488960 non-null  object
#  5   Nome da Rua        488960 non-null  object
#  6   Numero Rua         488667 non-null  object
#  7   Complemento        126566 non-null  object
#  8   Bairro             487003 non-null  object
#  9   Cep                488960 non-null  object
#  10  Produto            488960 non-null  object
#  11  Data da Coleta     488960 non-null  object
#  12  Valor de Venda     488960 non-null  object
#  13  Valor de Compra    228284 non-null  object
#  14  Unidade de Medida  488960 non-null  object
# ...

# %%
ca_2016_02['Valor de Venda'] = ca_2016_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2016_02['Valor de Compra'] = ca_2016_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2016_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488960 entries, 0 to 488959
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     488960 non-null  object
#  1   Estado - Sigla     488960 non-null  object
#  2   Municipio          488960 non-null  object
#  3   Revenda            488960 non-null  object
#  4   CNPJ da Revenda    488960 non-null  object
#  5   Nome da Rua        488960 non-null  object
#  6   Numero Rua         488667 non-null  object
#  7   Complemento        126566 non-null  object
#  8   Bairro             487003 non-null  object
#  9   Cep                488960 non-null  object
#  10  Produto            488960 non-null  object
#  11  Data da Coleta     488960 non-null  object
#  12  Valor de Venda     488960 non-null  float64
#  13  Valor de Compra    228284 non-null  float64
#  14  Unidade de Medida  488960 non-null  object
# ...

# %% [markdown]
# #### 2017

# %%
ca_2017_01 = pd.read_csv("rsc/ca-2017-01.csv", sep=';')

# %%
ca_2017_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio                   Revenda  \
# 0             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 1             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 2             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 3             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
# 4             SE             SP  GUARULHOS  AUTO POSTO SAKAMOTO LTDA
#
#        CNPJ da Revenda               Nome da Rua Numero Rua  \
# 0   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 1   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 2   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 3   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 4   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
#
#            Complemento      Bairro        Cep     Produto Data da Coleta  \
# 0  KM 210,5-SENT SP/RJ  BONSUCESSO  07178-580    GASOLINA     03/01/2017
# ...

# %%
ca_2017_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487659 entries, 0 to 487658
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     487659 non-null  object
#  1   Estado - Sigla     487659 non-null  object
#  2   Municipio          487659 non-null  object
#  3   Revenda            487659 non-null  object
#  4   CNPJ da Revenda    487659 non-null  object
#  5   Nome da Rua        487659 non-null  object
#  6   Numero Rua         487438 non-null  object
#  7   Complemento        128668 non-null  object
#  8   Bairro             485899 non-null  object
#  9   Cep                487659 non-null  object
#  10  Produto            487659 non-null  object
#  11  Data da Coleta     487659 non-null  object
#  12  Valor de Venda     487659 non-null  object
#  13  Valor de Compra    224745 non-null  object
#  14  Unidade de Medida  487659 non-null  object
# ...

# %%
ca_2017_01['Valor de Venda'] = ca_2017_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2017_01['Valor de Compra'] = ca_2017_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2017_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487659 entries, 0 to 487658
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     487659 non-null  object
#  1   Estado - Sigla     487659 non-null  object
#  2   Municipio          487659 non-null  object
#  3   Revenda            487659 non-null  object
#  4   CNPJ da Revenda    487659 non-null  object
#  5   Nome da Rua        487659 non-null  object
#  6   Numero Rua         487438 non-null  object
#  7   Complemento        128668 non-null  object
#  8   Bairro             485899 non-null  object
#  9   Cep                487659 non-null  object
#  10  Produto            487659 non-null  object
#  11  Data da Coleta     487659 non-null  object
#  12  Valor de Venda     487659 non-null  float64
#  13  Valor de Compra    224745 non-null  float64
#  14  Unidade de Medida  487659 non-null  object
# ...

# %%
ca_2017_02 = pd.read_csv("rsc/ca-2017-02.csv", sep=';')

# %%
ca_2017_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP  SOROCABA
# 1             SE             SP  SOROCABA
# 2             SE             SP  SOROCABA
# 3             NE             BA   ITABUNA
# 4             NE             BA   ITABUNA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3          LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4          LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#               Nome da Rua Numero Rua  Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306          NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306          NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
ca_2017_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300947 entries, 0 to 300946
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     300947 non-null  object
#  1   Estado - Sigla     300947 non-null  object
#  2   Municipio          300947 non-null  object
#  3   Revenda            300947 non-null  object
#  4   CNPJ da Revenda    300947 non-null  object
#  5   Nome da Rua        300947 non-null  object
#  6   Numero Rua         300761 non-null  object
#  7   Complemento        77397 non-null   object
#  8   Bairro             299989 non-null  object
#  9   Cep                300947 non-null  object
#  10  Produto            300947 non-null  object
#  11  Data da Coleta     300947 non-null  object
#  12  Valor de Venda     300947 non-null  object
#  13  Valor de Compra    131020 non-null  object
#  14  Unidade de Medida  300947 non-null  object
# ...

# %%
ca_2017_02['Valor de Venda'] = ca_2017_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2017_02['Valor de Compra'] = ca_2017_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2017_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300947 entries, 0 to 300946
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     300947 non-null  object
#  1   Estado - Sigla     300947 non-null  object
#  2   Municipio          300947 non-null  object
#  3   Revenda            300947 non-null  object
#  4   CNPJ da Revenda    300947 non-null  object
#  5   Nome da Rua        300947 non-null  object
#  6   Numero Rua         300761 non-null  object
#  7   Complemento        77397 non-null   object
#  8   Bairro             299989 non-null  object
#  9   Cep                300947 non-null  object
#  10  Produto            300947 non-null  object
#  11  Data da Coleta     300947 non-null  object
#  12  Valor de Venda     300947 non-null  float64
#  13  Valor de Compra    131020 non-null  float64
#  14  Unidade de Medida  300947 non-null  object
# ...

# %% [markdown]
# #### 2018

# %%
ca_2018_01 = pd.read_csv("rsc/ca-2018-01.csv", sep=';')

# %%
ca_2018_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             NE             BA  SALVADOR
# 1             NE             BA  SALVADOR
# 2             NE             BA  SALVADOR
# 3             NE             BA  SALVADOR
# 4              S             RS    CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 1                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 2                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 3                 PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua Complemento  Bairro        Cep  \
# 0         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# 1         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# 2         RUA EDISTIO PONDE        474         NaN   STIEP  41770-395
# ...

# %%
ca_2018_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469833 entries, 0 to 469832
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     469833 non-null  object
#  1   Estado - Sigla     469833 non-null  object
#  2   Municipio          469833 non-null  object
#  3   Revenda            469833 non-null  object
#  4   CNPJ da Revenda    469833 non-null  object
#  5   Nome da Rua        469833 non-null  object
#  6   Numero Rua         469485 non-null  object
#  7   Complemento        123062 non-null  object
#  8   Bairro             468412 non-null  object
#  9   Cep                469833 non-null  object
#  10  Produto            469833 non-null  object
#  11  Data da Coleta     469833 non-null  object
#  12  Valor de Venda     469833 non-null  object
#  13  Valor de Compra    188187 non-null  object
#  14  Unidade de Medida  469833 non-null  object
# ...

# %%
ca_2018_01['Valor de Venda'] = ca_2018_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2018_01['Valor de Compra'] = ca_2018_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2018_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469833 entries, 0 to 469832
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     469833 non-null  object
#  1   Estado - Sigla     469833 non-null  object
#  2   Municipio          469833 non-null  object
#  3   Revenda            469833 non-null  object
#  4   CNPJ da Revenda    469833 non-null  object
#  5   Nome da Rua        469833 non-null  object
#  6   Numero Rua         469485 non-null  object
#  7   Complemento        123062 non-null  object
#  8   Bairro             468412 non-null  object
#  9   Cep                469833 non-null  object
#  10  Produto            469833 non-null  object
#  11  Data da Coleta     469833 non-null  object
#  12  Valor de Venda     469833 non-null  float64
#  13  Valor de Compra    188187 non-null  float64
#  14  Unidade de Medida  469833 non-null  object
# ...

# %%
ca_2018_02 = pd.read_csv("rsc/ca-2018-02.csv", sep=';')

# %%
ca_2018_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla     Municipio  \
# 0              S             PR   PATO BRANCO
# 1              S             PR   PATO BRANCO
# 2              S             PR   PATO BRANCO
# 3              S             RS  PORTO ALEGRE
# 4              S             RS  PORTO ALEGRE
#
#                              Revenda      CNPJ da Revenda        Nome da Rua  \
# 0               SANTOS & MERLO LTDA.   79.854.667/0001-01      RUA TOCANTINS
# 1               SANTOS & MERLO LTDA.   79.854.667/0001-01      RUA TOCANTINS
# 2               SANTOS & MERLO LTDA.   79.854.667/0001-01      RUA TOCANTINS
# 3  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14  RUA EDUARDO PRADO
# 4  COMERCIAL DE COMBUSTIVEIS TK LTDA   91.438.796/0001-14  RUA EDUARDO PRADO
#
#   Numero Rua Complemento     Bairro        Cep     Produto Data da Coleta  \
# 0       2535         NaN     CENTRO  85501-010    GASOLINA     04/07/2018
# ...

# %%
ca_2018_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493169 entries, 0 to 493168
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     493169 non-null  object
#  1   Estado - Sigla     493169 non-null  object
#  2   Municipio          493169 non-null  object
#  3   Revenda            493169 non-null  object
#  4   CNPJ da Revenda    493169 non-null  object
#  5   Nome da Rua        493169 non-null  object
#  6   Numero Rua         492723 non-null  object
#  7   Complemento        127534 non-null  object
#  8   Bairro             491632 non-null  object
#  9   Cep                493169 non-null  object
#  10  Produto            493169 non-null  object
#  11  Data da Coleta     493169 non-null  object
#  12  Valor de Venda     493169 non-null  object
#  13  Valor de Compra    198303 non-null  object
#  14  Unidade de Medida  493169 non-null  object
# ...

# %%
ca_2018_02['Valor de Venda'] = ca_2018_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2018_02['Valor de Compra'] = ca_2018_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2018_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493169 entries, 0 to 493168
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     493169 non-null  object
#  1   Estado - Sigla     493169 non-null  object
#  2   Municipio          493169 non-null  object
#  3   Revenda            493169 non-null  object
#  4   CNPJ da Revenda    493169 non-null  object
#  5   Nome da Rua        493169 non-null  object
#  6   Numero Rua         492723 non-null  object
#  7   Complemento        127534 non-null  object
#  8   Bairro             491632 non-null  object
#  9   Cep                493169 non-null  object
#  10  Produto            493169 non-null  object
#  11  Data da Coleta     493169 non-null  object
#  12  Valor de Venda     493169 non-null  float64
#  13  Valor de Compra    198303 non-null  float64
#  14  Unidade de Medida  493169 non-null  object
# ...

# %% [markdown]
# #### 2019

# %%
ca_2019_01 = pd.read_csv("rsc/ca-2019-01.csv", sep=';')

# %%
ca_2019_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP  GUARULHOS
# 1             SE             SP  GUARULHOS
# 2             SE             SP  GUARULHOS
# 3             SE             SP  GUARULHOS
# 4              S             RS     CANOAS
#
#                                        Revenda      CNPJ da Revenda  \
# 0                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 1                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 2                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 3                     AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
#
#                 Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 2  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# ...

# %%
ca_2019_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496730 entries, 0 to 496729
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     496730 non-null  object
#  1   Estado - Sigla     496730 non-null  object
#  2   Municipio          496730 non-null  object
#  3   Revenda            496730 non-null  object
#  4   CNPJ da Revenda    496730 non-null  object
#  5   Nome da Rua        496730 non-null  object
#  6   Numero Rua         496355 non-null  object
#  7   Complemento        129327 non-null  object
#  8   Bairro             494911 non-null  object
#  9   Cep                496730 non-null  object
#  10  Produto            496730 non-null  object
#  11  Data da Coleta     496730 non-null  object
#  12  Valor de Venda     496730 non-null  object
#  13  Valor de Compra    191139 non-null  object
#  14  Unidade de Medida  496730 non-null  object
# ...

# %%
ca_2019_01['Valor de Venda'] = ca_2019_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2019_01['Valor de Compra'] = ca_2019_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2019_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496730 entries, 0 to 496729
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     496730 non-null  object
#  1   Estado - Sigla     496730 non-null  object
#  2   Municipio          496730 non-null  object
#  3   Revenda            496730 non-null  object
#  4   CNPJ da Revenda    496730 non-null  object
#  5   Nome da Rua        496730 non-null  object
#  6   Numero Rua         496355 non-null  object
#  7   Complemento        129327 non-null  object
#  8   Bairro             494911 non-null  object
#  9   Cep                496730 non-null  object
#  10  Produto            496730 non-null  object
#  11  Data da Coleta     496730 non-null  object
#  12  Valor de Venda     496730 non-null  float64
#  13  Valor de Compra    191139 non-null  float64
#  14  Unidade de Medida  496730 non-null  object
# ...

# %%
ca_2019_02 = pd.read_csv("rsc/ca-2019-02.csv", sep=';')

# %%
ca_2019_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0              S             RS    CANOAS
# 1              S             RS    CANOAS
# 2              S             RS    CANOAS
# 3             NE             BA   ITABUNA
# 4             NE             BA   ITABUNA
#
#                                        Revenda      CNPJ da Revenda  \
# 0  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 1  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 2  METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 3    LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
# 4    LOPES LEMOS COMERCIO DE COMBUSTIVEIS LTDA   00.231.792/0001-05
#
#                 Nome da Rua Numero Rua  Complemento       Bairro        Cep  \
# 0  AVENIDA GUILHERME SCHELL       6340          NaN       CENTRO  92310-000
# 1  AVENIDA GUILHERME SCHELL       6340          NaN       CENTRO  92310-000
# ...

# %%
ca_2019_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507299 entries, 0 to 507298
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     507299 non-null  object
#  1   Estado - Sigla     507299 non-null  object
#  2   Municipio          507299 non-null  object
#  3   Revenda            507299 non-null  object
#  4   CNPJ da Revenda    507299 non-null  object
#  5   Nome da Rua        507299 non-null  object
#  6   Numero Rua         507062 non-null  object
#  7   Complemento        132458 non-null  object
#  8   Bairro             505329 non-null  object
#  9   Cep                507299 non-null  object
#  10  Produto            507299 non-null  object
#  11  Data da Coleta     507299 non-null  object
#  12  Valor de Venda     507299 non-null  object
#  13  Valor de Compra    190730 non-null  object
#  14  Unidade de Medida  507299 non-null  object
# ...

# %%
ca_2019_02['Valor de Venda'] = ca_2019_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2019_02['Valor de Compra'] = ca_2019_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2019_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507299 entries, 0 to 507298
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     507299 non-null  object
#  1   Estado - Sigla     507299 non-null  object
#  2   Municipio          507299 non-null  object
#  3   Revenda            507299 non-null  object
#  4   CNPJ da Revenda    507299 non-null  object
#  5   Nome da Rua        507299 non-null  object
#  6   Numero Rua         507062 non-null  object
#  7   Complemento        132458 non-null  object
#  8   Bairro             505329 non-null  object
#  9   Cep                507299 non-null  object
#  10  Produto            507299 non-null  object
#  11  Data da Coleta     507299 non-null  object
#  12  Valor de Venda     507299 non-null  float64
#  13  Valor de Compra    190730 non-null  float64
#  14  Unidade de Medida  507299 non-null  object
# ...

# %% [markdown]
# #### 2020

# %%
ca_2020_01 = pd.read_csv("rsc/ca-2020-01.csv", sep=';')

# %%
ca_2020_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio                       Revenda  \
# 0             SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 1             SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 2             SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 3             SE             SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA
# 4             NE             BA   SALVADOR  PETROBRAS DISTRIBUIDORA S.A.
#
#        CNPJ da Revenda               Nome da Rua Numero Rua  \
# 0   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 1   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 2   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 3   49.051.667/0001-02  RODOVIA PRESIDENTE DUTRA        S/N
# 4   34.274.233/0015-08         RUA EDISTIO PONDE        474
#
#            Complemento      Bairro        Cep     Produto Data da Coleta  \
# 0  KM 210,5-SENT SP/RJ  BONSUCESSO  07178-580    GASOLINA     03/01/2020
# ...

# %%
ca_2020_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496663 entries, 0 to 496662
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     496663 non-null  object
#  1   Estado - Sigla     496663 non-null  object
#  2   Municipio          496663 non-null  object
#  3   Revenda            496663 non-null  object
#  4   CNPJ da Revenda    496663 non-null  object
#  5   Nome da Rua        496663 non-null  object
#  6   Numero Rua         496316 non-null  object
#  7   Complemento        129458 non-null  object
#  8   Bairro             494708 non-null  object
#  9   Cep                496663 non-null  object
#  10  Produto            496663 non-null  object
#  11  Data da Coleta     496663 non-null  object
#  12  Valor de Venda     496663 non-null  object
#  13  Valor de Compra    128975 non-null  object
#  14  Unidade de Medida  496663 non-null  object
# ...

# %%
ca_2020_01['Valor de Venda'] = ca_2020_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2020_01['Valor de Compra'] = ca_2020_01['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2020_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496663 entries, 0 to 496662
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     496663 non-null  object
#  1   Estado - Sigla     496663 non-null  object
#  2   Municipio          496663 non-null  object
#  3   Revenda            496663 non-null  object
#  4   CNPJ da Revenda    496663 non-null  object
#  5   Nome da Rua        496663 non-null  object
#  6   Numero Rua         496316 non-null  object
#  7   Complemento        129458 non-null  object
#  8   Bairro             494708 non-null  object
#  9   Cep                496663 non-null  object
#  10  Produto            496663 non-null  object
#  11  Data da Coleta     496663 non-null  object
#  12  Valor de Venda     496663 non-null  float64
#  13  Valor de Compra    128975 non-null  float64
#  14  Unidade de Medida  496663 non-null  object
# ...

# %%
ca_2020_02 = pd.read_csv("rsc/ca-2020-02.csv", sep=';')
# Out:
# C:\Users\mclar\AppData\Local\Temp\ipykernel_20348\2307808660.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   ca_2020_02 = pd.read_csv("rsc/ca-2020-02.csv", sep=';')

# %%
ca_2020_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             SP  SOROCABA
# 1             SE             SP  SOROCABA
# 2             SE             SP  SOROCABA
# 3             NE             BA  SALVADOR
# 4             NE             BA  SALVADOR
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
# 4                       PETROBRAS DISTRIBUIDORA S.A.   34.274.233/0015-08
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
ca_2020_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222637 entries, 0 to 222636
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     222637 non-null  object
#  1   Estado - Sigla     222637 non-null  object
#  2   Municipio          222637 non-null  object
#  3   Revenda            222637 non-null  object
#  4   CNPJ da Revenda    222637 non-null  object
#  5   Nome da Rua        222637 non-null  object
#  6   Numero Rua         222465 non-null  object
#  7   Complemento        54744 non-null   object
#  8   Bairro             221986 non-null  object
#  9   Cep                222637 non-null  object
#  10  Produto            222637 non-null  object
#  11  Data da Coleta     222637 non-null  object
#  12  Valor de Venda     222637 non-null  object
#  13  Valor de Compra    27037 non-null   object
#  14  Unidade de Medida  222637 non-null  object
# ...

# %%
ca_2020_02['Valor de Venda'] = ca_2020_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)
ca_2020_02['Valor de Compra'] = ca_2020_02['Valor de Compra'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2020_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222637 entries, 0 to 222636
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     222637 non-null  object
#  1   Estado - Sigla     222637 non-null  object
#  2   Municipio          222637 non-null  object
#  3   Revenda            222637 non-null  object
#  4   CNPJ da Revenda    222637 non-null  object
#  5   Nome da Rua        222637 non-null  object
#  6   Numero Rua         222465 non-null  object
#  7   Complemento        54744 non-null   object
#  8   Bairro             221986 non-null  object
#  9   Cep                222637 non-null  object
#  10  Produto            222637 non-null  object
#  11  Data da Coleta     222637 non-null  object
#  12  Valor de Venda     222637 non-null  float64
#  13  Valor de Compra    27037 non-null   float64
#  14  Unidade de Medida  222637 non-null  object
# ...

# %% [markdown]
# #### 2021

# %%
ca_2021_01 = pd.read_csv("rsc/ca-2021-01.csv", sep=';')

# %%
ca_2021_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla     Municipio  \
# 0              S             RS  SAO LEOPOLDO
# 1              S             RS  SAO LEOPOLDO
# 2              S             RS  SAO LEOPOLDO
# 3              S             RS  SAO LEOPOLDO
# 4              S             RS  SAO LEOPOLDO
#
#                                  Revenda      CNPJ da Revenda  \
# 0  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 1  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 2  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 3  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
# 4  POSTOS DE COMBUSTIVEIS REDESINOS LTDA   01.731.418/0001-31
#
#         Nome da Rua Numero Rua Complemento    Bairro        Cep  \
# 0  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 1  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# 2  AVENIDA FEITORIA       4288         NaN  FEITORIA  93048-000
# ...

# %%
ca_2021_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334681 entries, 0 to 334680
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     334681 non-null  object
#  1   Estado - Sigla     334681 non-null  object
#  2   Municipio          334681 non-null  object
#  3   Revenda            334681 non-null  object
#  4   CNPJ da Revenda    334681 non-null  object
#  5   Nome da Rua        334681 non-null  object
#  6   Numero Rua         334558 non-null  object
#  7   Complemento        68732 non-null   object
#  8   Bairro             334071 non-null  object
#  9   Cep                334681 non-null  object
#  10  Produto            334681 non-null  object
#  11  Data da Coleta     334681 non-null  object
#  12  Valor de Venda     334681 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  334681 non-null  object
# ...

# %%
ca_2021_01['Valor de Venda'] = ca_2021_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2021_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334681 entries, 0 to 334680
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     334681 non-null  object
#  1   Estado - Sigla     334681 non-null  object
#  2   Municipio          334681 non-null  object
#  3   Revenda            334681 non-null  object
#  4   CNPJ da Revenda    334681 non-null  object
#  5   Nome da Rua        334681 non-null  object
#  6   Numero Rua         334558 non-null  object
#  7   Complemento        68732 non-null   object
#  8   Bairro             334071 non-null  object
#  9   Cep                334681 non-null  object
#  10  Produto            334681 non-null  object
#  11  Data da Coleta     334681 non-null  object
#  12  Valor de Venda     334681 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  334681 non-null  object
# ...

# %%
ca_2021_02 = pd.read_csv("rsc/ca-2021-02.csv")

# %%
ca_2021_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             NE             CE  MARACANAU
# 1             NE             CE  MARACANAU
# 2             NE             CE  MARACANAU
# 3             NE             CE  MARACANAU
# 4             NE             CE  MARACANAU
#
#                                         Revenda     CNPJ da Revenda  \
# 0  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.  05.397.086/0001-51
# 1  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.  05.397.086/0001-51
# 2  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.  05.397.086/0001-51
# 3  BEZERRA & MENDES COMERCIAL DE PETRÓLEO LTDA.  05.397.086/0001-51
# 4                     LUIZA GLAURIA R T MENEZES  03.602.329/0001-10
#
#                               Nome da Rua Numero Rua Complemento  \
# 0  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# 1  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# 2  RODOVIA MARANGUAPE - FORTALEZA - KM 06        S/N         NaN
# ...

# %%
ca_2021_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472856 entries, 0 to 472855
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     472856 non-null  object
#  1   Estado - Sigla     472856 non-null  object
#  2   Municipio          472856 non-null  object
#  3   Revenda            472856 non-null  object
#  4   CNPJ da Revenda    472856 non-null  object
#  5   Nome da Rua        472856 non-null  object
#  6   Numero Rua         472664 non-null  object
#  7   Complemento        95775 non-null   object
#  8   Bairro             471737 non-null  object
#  9   Cep                472856 non-null  object
#  10  Produto            472856 non-null  object
#  11  Data da Coleta     472856 non-null  object
#  12  Valor de Venda     472856 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  472856 non-null  object
# ...

# %%
ca_2021_02['Valor de Venda'] = ca_2021_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2021_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472856 entries, 0 to 472855
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     472856 non-null  object
#  1   Estado - Sigla     472856 non-null  object
#  2   Municipio          472856 non-null  object
#  3   Revenda            472856 non-null  object
#  4   CNPJ da Revenda    472856 non-null  object
#  5   Nome da Rua        472856 non-null  object
#  6   Numero Rua         472664 non-null  object
#  7   Complemento        95775 non-null   object
#  8   Bairro             471737 non-null  object
#  9   Cep                472856 non-null  object
#  10  Produto            472856 non-null  object
#  11  Data da Coleta     472856 non-null  object
#  12  Valor de Venda     472856 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  472856 non-null  object
# ...

# %% [markdown]
# #### 2022

# %%
ca_2022_01 = pd.read_csv("rsc/ca-2022-01.csv", sep=';')

# %%
ca_2022_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio                    Revenda  \
# 0              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 1              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 2              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 3              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
# 4              N             AC  RIO BRANCO  AUTO POSTO AMAPA - EIRELI
#
#        CNPJ da Revenda       Nome da Rua Numero Rua Complemento Bairro  \
# 0   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN  AREAL
# 1   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN  AREAL
# 2   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN  AREAL
# 3   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN  AREAL
# 4   00.529.581/0001-53  VIA CHICO MENDES       3570         NaN  AREAL
#
#          Cep             Produto Data da Coleta Valor de Venda  \
# ...

# %%
ca_2022_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529424 entries, 0 to 529423
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     529424 non-null  object
#  1   Estado - Sigla     529424 non-null  object
#  2   Municipio          529424 non-null  object
#  3   Revenda            529424 non-null  object
#  4   CNPJ da Revenda    529424 non-null  object
#  5   Nome da Rua        529424 non-null  object
#  6   Numero Rua         529211 non-null  object
#  7   Complemento        113936 non-null  object
#  8   Bairro             527991 non-null  object
#  9   Cep                529424 non-null  object
#  10  Produto            529424 non-null  object
#  11  Data da Coleta     529424 non-null  object
#  12  Valor de Venda     529424 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  529424 non-null  object
# ...

# %%
ca_2022_01['Valor de Venda'] = ca_2022_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2022_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529424 entries, 0 to 529423
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     529424 non-null  object
#  1   Estado - Sigla     529424 non-null  object
#  2   Municipio          529424 non-null  object
#  3   Revenda            529424 non-null  object
#  4   CNPJ da Revenda    529424 non-null  object
#  5   Nome da Rua        529424 non-null  object
#  6   Numero Rua         529211 non-null  object
#  7   Complemento        113936 non-null  object
#  8   Bairro             527991 non-null  object
#  9   Cep                529424 non-null  object
#  10  Produto            529424 non-null  object
#  11  Data da Coleta     529424 non-null  object
#  12  Valor de Venda     529424 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  529424 non-null  object
# ...

# %%
ca_2022_02 = pd.read_csv("rsc/ca-2022-02.csv", sep=';')

# %%
ca_2022_02.head()
# Out:
#   Regiao - Sigla Estado - Sigla Municipio  \
# 0             SE             ES  COLATINA
# 1             SE             ES  COLATINA
# 2             SE             ES  COLATINA
# 3             SE             ES  COLATINA
# 4             SE             ES  COLATINA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
# 1  SAO FRANCISCO DE ASSIS COMERCIO DE COMBUSTIVEI...   08.519.545/0001-10
# 2                                 POSTO MOTOCAP LTDA   04.814.652/0001-10
# 3                                 POSTO MOTOCAP LTDA   04.814.652/0001-10
# 4                                 POSTO MOTOCAP LTDA   04.814.652/0001-10
#
#                Nome da Rua Numero Rua Complemento Bairro        Cep  \
# 0    PRACA FIDELIS FERRARI         35         NaN   LACE  29703-030
# 1    PRACA FIDELIS FERRARI         35         NaN   LACE  29703-030
# ...

# %%
ca_2022_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378078 entries, 0 to 378077
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     378078 non-null  object
#  1   Estado - Sigla     378078 non-null  object
#  2   Municipio          378078 non-null  object
#  3   Revenda            378078 non-null  object
#  4   CNPJ da Revenda    378078 non-null  object
#  5   Nome da Rua        378078 non-null  object
#  6   Numero Rua         377902 non-null  object
#  7   Complemento        81264 non-null   object
#  8   Bairro             377177 non-null  object
#  9   Cep                378078 non-null  object
#  10  Produto            378078 non-null  object
#  11  Data da Coleta     378078 non-null  object
#  12  Valor de Venda     378078 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  378078 non-null  object
# ...

# %%
ca_2022_02['Valor de Venda'] = ca_2022_02['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2022_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378078 entries, 0 to 378077
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     378078 non-null  object
#  1   Estado - Sigla     378078 non-null  object
#  2   Municipio          378078 non-null  object
#  3   Revenda            378078 non-null  object
#  4   CNPJ da Revenda    378078 non-null  object
#  5   Nome da Rua        378078 non-null  object
#  6   Numero Rua         377902 non-null  object
#  7   Complemento        81264 non-null   object
#  8   Bairro             377177 non-null  object
#  9   Cep                378078 non-null  object
#  10  Produto            378078 non-null  object
#  11  Data da Coleta     378078 non-null  object
#  12  Valor de Venda     378078 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  378078 non-null  object
# ...

# %% [markdown]
# #### 2023

# %%
ca_2023_01 = pd.read_csv("rsc/ca-2023-01.csv", sep=';')

# %%
ca_2023_01.head()
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP   SOROCABA
# 1             SE             SP   SOROCABA
# 2             SE             SP   SOROCABA
# 3             NE             AL  ARAPIRACA
# 4             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
# 4  COMERCIAL DE COMBUSTIVEIS E LUBRIFICANTES VITA...   02.817.655/0001-82
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
ca_2023_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431576 entries, 0 to 431575
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     431576 non-null  object
#  1   Estado - Sigla     431576 non-null  object
#  2   Municipio          431576 non-null  object
#  3   Revenda            431576 non-null  object
#  4   CNPJ da Revenda    431576 non-null  object
#  5   Nome da Rua        431576 non-null  object
#  6   Numero Rua         431469 non-null  object
#  7   Complemento        98576 non-null   object
#  8   Bairro             430748 non-null  object
#  9   Cep                431576 non-null  object
#  10  Produto            431576 non-null  object
#  11  Data da Coleta     431576 non-null  object
#  12  Valor de Venda     431576 non-null  object
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  431576 non-null  object
# ...

# %%
ca_2023_01['Valor de Venda'] = ca_2023_01['Valor de Venda'].str.replace(',', '.', regex=True).astype(float)

# %%
ca_2023_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431576 entries, 0 to 431575
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     431576 non-null  object
#  1   Estado - Sigla     431576 non-null  object
#  2   Municipio          431576 non-null  object
#  3   Revenda            431576 non-null  object
#  4   CNPJ da Revenda    431576 non-null  object
#  5   Nome da Rua        431576 non-null  object
#  6   Numero Rua         431469 non-null  object
#  7   Complemento        98576 non-null   object
#  8   Bairro             430748 non-null  object
#  9   Cep                431576 non-null  object
#  10  Produto            431576 non-null  object
#  11  Data da Coleta     431576 non-null  object
#  12  Valor de Venda     431576 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  431576 non-null  object
# ...

# %% [markdown]
# #### Cocatenação

# %%
ca_2004 = pd.concat([ca_2004_01, ca_2004_02])
caminho_04 = 'anos_concatenados/ca_2004.csv'
ca_2004.to_csv(caminho_04, index=False)

# %%
ca_2005 = pd.concat([ca_2005_01, ca_2005_02])
caminho_05 = 'anos_concatenados/ca_2005.csv'
ca_2005.to_csv(caminho_05, index=False)

# %%
ca_2006 = pd.concat([ca_2006_01, ca_2006_02])
caminho_06 = 'anos_concatenados/ca_2006.csv'
ca_2006.to_csv(caminho_06, index=False)

# %%
ca_2007 = pd.concat([ca_2007_01, ca_2007_02])
caminho_07 = 'anos_concatenados/ca_2007.csv'
ca_2007.to_csv(caminho_07, index=False)

# %%
ca_2008 = pd.concat([ca_2008_01, ca_2008_02])
caminho_08 = 'anos_concatenados/ca_2008.csv'
ca_2008.to_csv(caminho_08, index=False)

# %%
ca_2009 = pd.concat([ca_2009_01, ca_2009_02])
caminho_09 = 'anos_concatenados/ca_2009.csv'
ca_2009.to_csv(caminho_09, index=False)

# %%
ca_2010 = pd.concat([ca_2010_01, ca_2010_02])
caminho_10 = 'anos_concatenados/ca_2010.csv'
ca_2010.to_csv(caminho_10, index=False)

# %%
ca_2011 = pd.concat([ca_2011_01, ca_2011_02])
caminho_11 = 'anos_concatenados/ca_2011.csv'
ca_2011.to_csv(caminho_11, index=False)

# %%
ca_2012 = pd.concat([ca_2012_01, ca_2012_02])
caminho_12 = 'anos_concatenados/ca_2012.csv'
ca_2012.to_csv(caminho_12, index=False)

# %%
ca_2013 = pd.concat([ca_2013_01, ca_2013_02])
caminho_13 = 'anos_concatenados/ca_2013.csv'
ca_2013.to_csv(caminho_13, index=False)

# %%
ca_2014 = pd.concat([ca_2014_01, ca_2014_02])
caminho_14 = 'anos_concatenados/ca_2014.csv'
ca_2014.to_csv(caminho_14, index=False)

# %%
ca_2015 = pd.concat([ca_2015_01, ca_2015_02])
caminho_15 = 'anos_concatenados/ca_2015.csv'
ca_2015.to_csv(caminho_15, index=False)

# %%
ca_2016 = pd.concat([ca_2016_01, ca_2016_02])
caminho_16 = 'anos_concatenados/ca_2016.csv'
ca_2016.to_csv(caminho_16, index=False)

# %%
ca_2017 = pd.concat([ca_2017_01, ca_2017_02])
caminho_17 = 'anos_concatenados/ca_2017.csv'
ca_2017.to_csv(caminho_17, index=False)

# %%
ca_2018 = pd.concat([ca_2018_01, ca_2018_02])
caminho_18 = 'anos_concatenados/ca_2018.csv'
ca_2018.to_csv(caminho_18, index=False)

# %%
ca_2019 = pd.concat([ca_2019_01, ca_2019_02])
caminho_19 = 'anos_concatenados/ca_2019.csv'
ca_2019.to_csv(caminho_19, index=False)

# %%
ca_2020 = pd.concat([ca_2020_01, ca_2020_02])
caminho_20 = 'anos_concatenados/ca_2020.csv'
ca_2020.to_csv(caminho_20, index=False)

# %%
ca_2021 = pd.concat([ca_2021_01, ca_2021_02])
caminho_21 = 'anos_concatenados/ca_2021.csv'
ca_2021.to_csv(caminho_21, index=False)

# %%
ca_2022 = pd.concat([ca_2022_01, ca_2022_02])
caminho_22 = 'anos_concatenados/ca_2022.csv'
ca_2022.to_csv(caminho_22, index=False)

# %%
caminho_23 = 'anos_concatenados/ca_2023.csv'
ca_2023_01.to_csv(caminho_23, index=False)
