# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
ano_2007 = pd.read_csv("dataset/Leitos_2007.csv")
ano_2008 = pd.read_csv("dataset/Leitos_2008.csv")
ano_2009 = pd.read_csv("dataset/Leitos_2009.csv")
ano_2010 = pd.read_csv("dataset/Leitos_2010.csv")
ano_2011 = pd.read_csv("dataset/Leitos_2011.csv")
ano_2012 = pd.read_csv("dataset/Leitos_2012.csv")
ano_2013 = pd.read_csv("dataset/Leitos_2013.csv")
ano_2014 = pd.read_csv("dataset/Leitos_2014.csv")
ano_2015 = pd.read_csv("dataset/Leitos_2015.csv")
ano_2016 = pd.read_csv("dataset/Leitos_2016.csv")
ano_2017 = pd.read_csv("dataset/Leitos_2017.csv")
ano_2018 = pd.read_csv("dataset/Leitos_2018.csv")
ano_2019 = pd.read_csv("dataset/Leitos_2019.csv")
ano_2020 = pd.read_csv("dataset/Leitos_2020.csv")
ano_2021 = pd.read_csv("dataset/Leitos_2021.csv")
ano_2022 = pd.read_csv("dataset/Leitos_2022.csv")
ano_2023 = pd.read_csv("dataset/Leitos_2023.csv")

# %%
todos_anos = pd.concat([ano_2007,ano_2008,ano_2009,ano_2010,ano_2011,ano_2012,ano_2013,ano_2014,ano_2015,
                        ano_2016,ano_2017,ano_2018,ano_2019,ano_2020,ano_2021,ano_2022,ano_2023])
caminho = 'todos_anos.csv'
todos_anos.to_csv(caminho, index= False)

# %%
todos_anos_pd = pd.read_csv('todos_anos.csv')

# %%
columns_to_select = ['LEITOS EXISTENTE', 'LEITOS SUS', 'UTI TOTAL - EXIST',
                     'UTI TOTAL - SUS', 'UTI ADULTO - EXIST', 'UTI ADULTO - SUS',
                     'UTI PEDIATRICO - EXIST', 'UTI PEDIATRICO - SUS', 'UTI NEONATAL - EXIST',
                     'UTI NEONATAL - SUS', 'UTI QUEIMADO - EXIST', 'UTI QUEIMADO - SUS',
                     'UTI CORONARIANA - EXIST', 'UTI CORONARIANA - SUS']

# %%
data_numbers = todos_anos_pd[columns_to_select]

# %%
X = data_numbers[['LEITOS EXISTENTE']]
y = data_numbers["LEITOS SUS"]

# %%
import math


for i in range(len(y)):
    if math.isnan(y[i]):
        y[i] = 0
        

X = np.nan_to_num(X)
# Out:
# C:\Users\mclar\AppData\Local\Temp\ipykernel_17664\2437110573.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[i] = 0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue') 
plt.show()

# %%
print(f"Coefficient (slope): {regressor.coef_[0]}")
# Out:
# Coefficient (slope): 0.7573531921608612
