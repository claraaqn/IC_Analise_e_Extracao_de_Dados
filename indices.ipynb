# %%
import pandas as pd
from scipy.stats import shapiro, mannwhitneyu
from statsmodels.tsa.stattools import adfuller

# %%
indice_gasolina = pd.read_csv('indices_gasolina.csv')

# %%
indice_gasolina['Valor de Venda'].count()
# Out:
# 4737007

# %%
# Normalidade dos dados de Venda
stat, p = shapiro(indice_gasolina['Valor de Venda'])
print('Estatística do teste:', stat)
print('p-valor:', p)
if p < 0.05:
    print('Os dados não são normalmente distribuídos')
else:
    print('Os dados são normalmente distribuídos')
# Out:
# Estatística do teste: 0.8298118114471436
# p-valor: 0.0
# Os dados não são normalmente distribuídos
# c:\Users\mclar\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
import matplotlib.pyplot as plt
from scipy.stats import probplot

quantis_teoricos, quantis_observados = probplot(indice_gasolina['Valor de Venda'], dist='norm', fit=False)

plt.figure(figsize=(8, 6))
plt.scatter(quantis_teoricos, quantis_observados, alpha=0.5)
plt.plot(quantis_teoricos, quantis_teoricos, color='red', linestyle='--')
plt.title('Gráfico Q-Q Plot')
plt.xlabel('Quantis Teóricos')
plt.ylabel('Quantis Observados')
plt.grid(True)
plt.show()

# %%
# Tendência dos dados de Venda
trend_stat, p_trend = mannwhitneyu(indice_gasolina['Ano'], indice_gasolina['Valor de Venda'])
print('Estatística do teste de tendência:', trend_stat)
print('p-valor:', p_trend)
if p_trend < 0.05:
    print('Os dados têm tendência')
else:
    print('Os dados não têm tendência')
# Out:
# Estatística do teste de tendência: 22439235318049.0
# p-valor: 0.0
# Os dados têm tendência

# %%
media_valor_venda_por_ano = indice_gasolina.groupby('Ano')['Valor de Venda'].mean()

# Aplicar o teste Dickey-Fuller aumentado na série de médias
adf_stat, p_adf, _, _, _, _ = adfuller(media_valor_venda_por_ano)
print('Estatística do teste Dickey-Fuller:', adf_stat)
print('p-valor:', p_adf)
if p_adf < 0.05:
    print('Os dados não são estacionários')
else:
    print('Os dados são estacionários')
# Out:
# Estatística do teste Dickey-Fuller: 2.8506747129511902
# p-valor: 1.0
# Os dados são estacionários

# %%
indice_diesel = pd.read_csv('indices_disel.csv')

# %%
# Normalidade dos dados de Venda
stat, p = shapiro(indice_diesel['Valor de Venda'])
print('Estatística do teste:', stat)
print('p-valor:', p)
if p < 0.05:
    print('Os dados não são normalmente distribuídos')
else:
    print('Os dados são normalmente distribuídos')
# Out:
# Estatística do teste: 0.7198355197906494
# p-valor: 0.0
# Os dados não são normalmente distribuídos
# c:\Users\mclar\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
import matplotlib.pyplot as plt
from scipy.stats import probplot

quantis_teoricos, quantis_observados = probplot(indice_diesel['Valor de Venda'], dist='norm', fit=False)

plt.figure(figsize=(8, 6))
plt.scatter(quantis_teoricos, quantis_observados, alpha=0.5)
plt.plot(quantis_teoricos, quantis_teoricos, color='red', linestyle='--')
plt.title('Gráfico Q-Q Plot')
plt.xlabel('Quantis Teóricos')
plt.ylabel('Quantis Observados')
plt.grid(True)
plt.show()

# %%
# Tendência dos dados de Venda
trend_stat, p_trend = mannwhitneyu(indice_diesel['Ano'], indice_diesel['Valor de Venda'])
print('Estatística do teste de tendência:', trend_stat)
print('p-valor:', p_trend)
if p_trend < 0.05:
    print('Os dados têm tendência')
else:
    print('Os dados não têm tendência')
# Out:
# Estatística do teste de tendência: 11021184913489.0
# p-valor: 0.0
# Os dados têm tendência

# %%
media_valor_venda_por_ano = indice_diesel.groupby('Ano')['Valor de Venda'].mean()

# Aplicar o teste Dickey-Fuller aumentado na série de médias
adf_stat, p_adf, _, _, _, _ = adfuller(media_valor_venda_por_ano)
print('Estatística do teste Dickey-Fuller:', adf_stat)
print('p-valor:', p_adf)
if p_adf < 0.05:
    print('Os dados não são estacionários')
else:
    print('Os dados são estacionários')
# Out:
# Estatística do teste Dickey-Fuller: 1.9969628283201941
# p-valor: 0.9986689917062539
# Os dados são estacionários
